# %%
# Cell 1 — imports
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sys

import os
os.makedirs('../results', exist_ok=True)

sys.path.append('..')

# Dataset is already QC'd and filtered, so we can skip those steps. Start with normalization and clustering.
from src.preprocess import run_normalization, save_checkpoint, load_checkpoint
from src.cluster import run_clustering_pipeline
from src.visualize import plot_umap
from src.annotate import score_gene_set, export_marker_table, find_marker_genes

sc.settings.verbosity = 3
sc.settings.figdir = '../results/'

# %%
# Cell 2 - Load Data
adata = sc.read_h5ad('../data/SEAAD_microglia.h5ad')
print("Microglia dataset loaded") 
print(adata)

metadata = pd.read_excel('../data/SEAAD_donor_metadata.xlsx')
print("Clinical columns:")
print(metadata.columns.tolist())

neuropath = pd.read_csv('../data/SEAAD_neuropathology.csv')
print("Neuropathology columns:")
print(neuropath.columns.tolist())

print("\n--- donor ID column in adata.obs ---")
donor_cols = [c for c in adata.obs.columns if any(x in c.lower() for x in ['donor', 'external', 'specimen'])]
print(donor_cols)
print(adata.obs[donor_cols].head(5))
# Out:
# Microglia dataset loaded
# AnnData object with n_obs × n_vars = 240651 × 36601
# ...

# %%
# Cell 3 - Inspecting Clinical Variables

# Key clinical variables not found are commented out
key_clinical = [
    'Cognitive Status',
    'Braak', 
    'CERAD score',
    'Overall AD neuropathological Change',
    'Thal', 
    'APOE Genotype',
    'Severely Affected Donor',
    'Sex',
    'Age at Death'
]

for col in key_clinical:
    if col in adata.obs.columns:
        print(f"\n{col}:")
        print(adata.obs[col].value_counts())
    else:
        print(f"\n{col}: NOT FOUND")
# Out:
# Cognitive Status:
# Cognitive Status
# No dementia    121506
# Dementia       119145
# Name: count, dtype: int64
#
# Braak:
# Braak
# Braak V      90805
# Braak IV     59138
# Braak VI     48516
# Braak III    17893
# Braak II     17536
# Braak 0       6763
# Name: count, dtype: int64
#
# CERAD score:
# CERAD score
# Moderate    84540
# Frequent    82094
# Absent      45988
# Sparse      28029
# Name: count, dtype: int64
#
# Overall AD neuropathological Change:
# Overall AD neuropathological Change
# High            123712
# Intermediate     50349
# Low              43458
# Not AD           23132
# Name: count, dtype: int64
#
# Thal:
# Thal
# Thal 4    85565
# Thal 5    59597
# Thal 3    29986
# Thal 2    23599
# Thal 0    23132
# Thal 1    18772
# Name: count, dtype: int64
#
# APOE Genotype:
# APOE Genotype
# 3/3    143325
# 3/4     47881
# 2/3     28330
# 4/4     16741
# 2/4      3666
# 2/2       708
# Name: count, dtype: int64
#
# Severely Affected Donor:
# ...

# %%
# Cell 4 - Inspect Existing Cell Type Annotations

print("Subclass labels:")
print(adata.obs['Subclass'].value_counts())

print("\nSupertype labels:")
print(adata.obs['Supertype'].value_counts())

print("\nClass labels:")
print(adata.obs['Class'].value_counts())
# Out:
# Subclass labels:
# Subclass
# Microglia-PVM    240651
# Name: count, dtype: int64
#
# Supertype labels:
# Supertype
# Micro-PVM_2            141248
# Micro-PVM_2_3-SEAAD     53815
# Micro-PVM_3-SEAAD       29805
# Micro-PVM_1              7909
# Lymphocyte               4607
# Micro-PVM_4-SEAAD        1767
# Micro-PVM_2_1-SEAAD      1458
# Monocyte                   42
# Name: count, dtype: int64
#
# Class labels:
# Class
# Non-neuronal and Non-neural    240651
# Name: count, dtype: int64

# %%
# =============================================================================
# Cell 5 (rewritten) - Matrix provenance & normalization verification
#
# Replaces the previous version, which sampled genes via
#   np.where(X.sum(0) > 0)[0][:5]
# That takes the first 5 gene INDICES passing a >0 filter, not 5 expressed
# genes. Because var_names are in genomic order, it sampled chr1-start
# lncRNAs / olfactory receptors and printed all zeros.
#
# Goal: prove (not infer) what is in .X, and collect the metadata needed
# for downstream filtering and confound checks.
# =============================================================================

import numpy as np
import pandas as pd
import scipy.sparse as sp

RNG = np.random.default_rng(0)
SEP = "=" * 78


def _dense_rows(M, idx):
    """Return dense array for the given row indices of a sparse/dense matrix."""
    sub = M[idx]
    return sub.toarray() if sp.issparse(sub) else np.asarray(sub)


# -----------------------------------------------------------------------------
# CHECK 1 - Object inventory
# -----------------------------------------------------------------------------
print(SEP)
print("CHECK 1 - OBJECT INVENTORY")
print(SEP)

print(f"shape                : {adata.shape[0]:,} cells x {adata.shape[1]:,} genes")
print(f"X type / dtype       : {type(adata.X).__name__} / {adata.X.dtype}")
print(f"adata.raw is None    : {adata.raw is None}")
print(f"layers               : {list(adata.layers.keys())}")
print(f"uns keys             : {list(adata.uns.keys())}")

if "log1p" in adata.uns:
    print(f"uns['log1p']         : {adata.uns['log1p']}")
    print("  NOTE: this key records that sc.pp.log1p ran at SOME point, possibly")
    print("  on a parent object before subsetting. It says nothing about whether")
    print("  normalize_total ran first. Check 4 settles that.")

# Fuzzy-match the obs columns we care about downstream.
WANTED = {
    "donor":     ["donor", "individual", "subject", "specimen"],
    "region":    ["region", "structure", "area", "roi"],
    "assay":     ["assay", "chemistry", "method", "platform", "library", "modality"],
    "celltype":  ["subclass", "supertype", "class", "cell_type", "celltype", "cluster"],
    "pathology": ["braak", "thal", "cerad", "adnc", "cps", "pseudoprog", "cognitive", "dementia", "apoe"],
    "qc":        ["total_counts", "n_genes", "pct_counts", "doublet", "fraction_mito"],
}

print("\nobs columns of interest:")
obs_lower = {c.lower(): c for c in adata.obs.columns}
for group, keys in WANTED.items():
    hits = sorted({orig for low, orig in obs_lower.items()
                   if any(k in low for k in keys)})
    print(f"  {group:<10}: {hits if hits else 'NONE FOUND'}")

print(f"\ntotal obs columns    : {len(adata.obs.columns)}")


# -----------------------------------------------------------------------------
# CHECK 2 - Pick genuinely expressed genes (fixes the original bug)
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 2 - GENE SELECTION")
print(SEP)

gene_totals = np.asarray(adata.X.sum(axis=0)).ravel()
top_idx = np.argsort(-gene_totals)[:8]
top_genes = adata.var_names[top_idx].tolist()

print("Top 8 genes by summed expression:")
for g, i in zip(top_genes, top_idx):
    print(f"  {g:<15} total={gene_totals[i]:,.0f}")

n_detected = int((gene_totals > 0).sum())
print(f"\ngenes with any expression: {n_detected:,} / {adata.n_vars:,} "
      f"({100 * n_detected / adata.n_vars:.1f}%)")

# Sanity: these should be recognizable (MT-, RP*, CX3CR1, P2RY12, CSF1R, FTH1, B2M).
# If you see OR4F5 / AL627309.x here, the sort direction is wrong.


# -----------------------------------------------------------------------------
# CHECK 3 - UMIs layer integrity
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 3 - UMIs LAYER")
print(SEP)

HAS_UMIS = "UMIs" in adata.layers
if not HAS_UMIS:
    print("!! No 'UMIs' layer. Raw counts unavailable -> pseudobulk DE in cell 12")
    print("   cannot be built as true CPM. Checks 4b/5 will be skipped.")
else:
    n_probe = 1000
    probe = RNG.choice(adata.n_obs, size=min(n_probe, adata.n_obs), replace=False)
    U = _dense_rows(adata.layers["UMIs"], probe)

    is_int = np.allclose(U, np.round(U))
    lib = U.sum(axis=1)

    print(f"dtype                : {adata.layers['UMIs'].dtype}")
    print(f"integer-valued       : {is_int}")
    print(f"min / max            : {U.min():.4f} / {U.max():.0f}")
    print(f"library size median  : {np.median(lib):,.0f}")
    print(f"library size IQR     : {np.percentile(lib, 25):,.0f} - {np.percentile(lib, 75):,.0f}")

    if not is_int:
        print("  !! Non-integer -> this is NOT raw counts. Do not use for pseudobulk.")


# -----------------------------------------------------------------------------
# CHECK 4 - THE DECISIVE TEST: is .X normalized, or only log-transformed?
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 4 - NORMALIZATION TARGET (expm1 row sums)")
print(SEP)

n_probe = 1000
probe = RNG.choice(adata.n_obs, size=min(n_probe, adata.n_obs), replace=False)

Xs = adata.X[probe]
row_sums = np.asarray(Xs.expm1().sum(axis=1)).ravel() if sp.issparse(Xs) \
           else np.expm1(np.asarray(Xs)).sum(axis=1)

mean_rs, std_rs = row_sums.mean(), row_sums.std()
cv = std_rs / mean_rs if mean_rs else np.inf

print(f"cells probed         : {len(probe):,}")
print(f"expm1 row sum mean   : {mean_rs:,.2f}")
print(f"expm1 row sum std    : {std_rs:,.4f}")
print(f"coefficient of var   : {cv:.3e}")
print(f"min / max            : {row_sums.min():,.2f} / {row_sums.max():,.2f}")

NORMALIZED = cv < 1e-4
if NORMALIZED:
    print(f"\n  -> CONSTANT row sums. normalize_total DID run.")
    print(f"  -> target_sum = {mean_rs:,.0f}")
else:
    print("\n  -> ROW SUMS VARY. normalize_total did NOT run (log1p only).")
    print("  -> DAM/Homeostatic scores are contaminated by library size.")
    print("  -> Cells 8-12 must be rerun after normalize_total + log1p.")

# 4b - correlate residual variation with library size (diagnostic if not normalized)
if HAS_UMIS and not NORMALIZED:
    from scipy.stats import spearmanr
    U_probe = _dense_rows(adata.layers["UMIs"], probe)
    rho, p = spearmanr(row_sums, U_probe.sum(axis=1))
    print(f"  row sum vs library size: rho={rho:.3f}, p={p:.2e}")
    print("  (strong positive rho confirms depth is leaking into .X)")


# -----------------------------------------------------------------------------
# CHECK 5 - Reconstruct .X from UMIs to pin the exact target
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 5 - RECONSTRUCTION FROM RAW COUNTS")
print(SEP)

if not HAS_UMIS:
    print("skipped (no UMIs layer)")
else:
    n_recon = 25
    ridx = RNG.choice(adata.n_obs, size=n_recon, replace=False)
    Xr = _dense_rows(adata.X, ridx)
    Ur = _dense_rows(adata.layers["UMIs"], ridx)
    libr = Ur.sum(axis=1, keepdims=True)

    candidates = [1e4, 1e6, float(round(mean_rs)) if NORMALIZED else 1e5]
    candidates = sorted(set(c for c in candidates if c > 0))

    print(f"{'target':>12}  {'max |diff|':>12}  {'mean |diff|':>12}   verdict")
    best, best_err = None, np.inf
    for t in candidates:
        with np.errstate(divide="ignore", invalid="ignore"):
            recon = np.log1p(np.divide(Ur, libr, where=libr > 0) * t)
        diff = np.abs(recon - Xr)
        mx, mn = diff.max(), diff.mean()
        verdict = "MATCH" if mx < 1e-6 else ("close" if mx < 1e-2 else "no")
        print(f"{t:>12,.0f}  {mx:>12.3e}  {mn:>12.3e}   {verdict}")
        if mx < best_err:
            best, best_err = t, mx

    if best_err < 1e-6:
        print(f"\n  -> CONFIRMED: .X = log1p(UMIs / library_size * {best:,.0f})")
        print("  -> .X and layers['UMIs'] are mutually consistent.")
    else:
        print(f"\n  -> No exact match (best {best:,.0f}, err {best_err:.3e}).")
        print("  -> .X may have been derived by a different route (e.g. scran, ")
        print("     median-of-ratios, or a target not tested). Investigate before")
        print("     treating .X and UMIs as the same underlying data.")


# -----------------------------------------------------------------------------
# CHECK 6 - Marker detection rates on a real sample
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 6 - MARKER DETECTION RATES")
print(SEP)

markers = ["P2RY12", "CX3CR1", "CSF1R", "TMEM119", "TREM2", "APOE",
           "SALL1", "HEXB", "MERTK", "PROS1", "LYZ", "CD52", "SPP1", "ITGAX"]

n_probe = min(20000, adata.n_obs)
probe = RNG.choice(adata.n_obs, size=n_probe, replace=False)
name_to_idx = {g: i for i, g in enumerate(adata.var_names)}

print(f"(sampled {n_probe:,} cells)\n")
print(f"{'gene':<10} {'detected %':>11} {'mean (nonzero)':>15}  note")
for g in markers:
    if g not in name_to_idx:
        print(f"{g:<10} {'NOT FOUND':>11}")
        continue
    col = adata.X[probe, name_to_idx[g]]
    vals = col.toarray().ravel() if sp.issparse(col) else np.asarray(col).ravel()
    pct = 100 * (vals > 0).mean()
    mu = vals[vals > 0].mean() if (vals > 0).any() else 0.0
    note = "<- sparse; weak signature member" if pct < 40 else ""
    print(f"{g:<10} {pct:>10.1f}% {mu:>15.3f}  {note}")


# -----------------------------------------------------------------------------
# CHECK 7 - Composition: cell type, region, assay
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 7 - COMPOSITION")
print(SEP)


def show_counts(colnames, label, max_rows=25):
    for c in colnames:
        if c in adata.obs.columns:
            vc = adata.obs[c].value_counts()
            print(f"\n{label} -- '{c}' ({vc.shape[0]} levels):")
            print(vc.head(max_rows).to_string())
            return c
    print(f"\n{label}: no matching obs column found")
    return None


ct_col = show_counts(
    [c for c in adata.obs.columns
     if any(k in c.lower() for k in ["subclass", "class", "cell_type", "celltype"])],
    "CELL TYPE",
)
if ct_col:
    print("\n  -> Note the exact labels for non-microglial populations.")
    print("     These must be excluded BEFORE donor-level aggregation in cells 9-12.")
    print("     LYZ and CD52 are in the DAM signature and are expressed by")
    print("     monocytes/lymphocytes, so leaving them in inflates DAM scores.")

show_counts([c for c in adata.obs.columns
             if any(k in c.lower() for k in ["region", "structure"])], "REGION")

assay_col = show_counts([c for c in adata.obs.columns
                         if any(k in c.lower() for k in
                                ["assay", "chemistry", "method", "modality", "platform"])],
                        "ASSAY")


# -----------------------------------------------------------------------------
# CHECK 8 - QC metrics for the depth-confound test
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("CHECK 8 - QC METRICS AVAILABILITY")
print(SEP)

qc_present = [c for c in ["total_counts", "n_genes_by_counts", "n_genes",
                          "pct_counts_mt", "pct_counts_ribo"]
              if c in adata.obs.columns]
print(f"present in obs: {qc_present if qc_present else 'NONE'}")

if "total_counts" not in adata.obs.columns and HAS_UMIS:
    print("\ncomputing total_counts from layers['UMIs'] ...")
    adata.obs["total_counts"] = np.asarray(adata.layers["UMIs"].sum(axis=1)).ravel()
    print(adata.obs["total_counts"].describe().to_string())

print("\nAfter cell 8 runs, test the depth confound:")
print("  from scipy.stats import spearmanr")
print("  spearmanr(adata.obs['DAM_score'], adata.obs['total_counts'])")
print("  A strong positive rho means the DAM score is partly a QC metric,")
print("  which would be an alternative explanation for the Result 1 trend.")


# -----------------------------------------------------------------------------
# VERDICT
# -----------------------------------------------------------------------------
print("\n" + SEP)
print("VERDICT")
print(SEP)

if NORMALIZED:
    print(f"[OK]   .X is log1p-normalized (target_sum = {mean_rs:,.0f})")
    print("       score_genes in cell 8 operated on the correct matrix.")
    print("       Pass use_raw=False explicitly for clarity (behaviour unchanged;")
    print("       adata.raw is None so it already resolved to False).")
else:
    print("[STOP] .X is NOT library-size normalized. Rerun normalize_total +")
    print("       log1p, then rerun cells 8 onward.")

if HAS_UMIS:
    print("[OK]   layers['UMIs'] holds raw counts -> build cell 12 pseudobulk from")
    print("       THIS layer (sum per donor, then CPM), not from .X.")
    print("       Summing log-normalized .X values per donor is not pseudobulk.")
else:
    print("[WARN] No raw counts available for pseudobulk DE.")

print("\nStill open from the cell 8 review:")
print("  - TREM2 sits in the homeostatic signature (see Check 6 detection rate)")
print("  - non-microglial cells not yet filtered (see Check 7 labels)")
print("  - DAM score vs total_counts correlation not yet measured (Check 8)")
print("  - 27 vs 8 gene asymmetry between the two signatures")
print("  - region / assay pooling not yet assessed against pathology variables")

print("\nREADME Methods line, once the above passes:")
if NORMALIZED:
    print(f'  "Expression matrix verified as log1p-normalized to a target sum of '
          f'{mean_rs:,.0f}; raw counts retained in layers[\'UMIs\'] and used for '
          f'pseudobulk aggregation."')
# Out:
# ...
# CHECK 1 - OBJECT INVENTORY
# ...
# shape                : 240,651 cells x 36,601 genes
# X type / dtype       : csr_matrix / float64
# adata.raw is None    : True
# layers               : ['UMIs']
# uns keys             : ['Subclass_colors', 'Supertype_colors', 'log1p', 'neighbors', 'umap', 'Cognitive Status_colors', 'Braak_colors', 'Severely Affected Donor_colors']
# uns['log1p']         : {}
#   NOTE: this key records that sc.pp.log1p ran at SOME point, possibly
#   on a parent object before subsetting. It says nothing about whether
#   normalize_total ran first. Check 4 settles that.
#
# obs columns of interest:
#   donor     : ['Donor ID', 'Severely Affected Donor']
# ...

# %%
# Cell 6 - Visualize existing UMAP embeddings colored by clinical variables

# fix supertype colors
supertypes = adata.obs['Supertype'].cat.categories.tolist()
color_map = {
    'Micro-PVM_1':         '#2196F3',  # blue
    'Micro-PVM_2':         '#4CAF50',  # green
    'Micro-PVM_2_1-SEAAD': '#F44336',  # red
    'Micro-PVM_2_3-SEAAD': '#FF9800',  # orange
    'Micro-PVM_3-SEAAD':   '#9C27B0',  # purple
    'Micro-PVM_4-SEAAD':   '#E91E63',  # pink
    'Monocyte':            '#795548',  # brown
    'Lymphocyte':          '#607D8B',  # grey
}
adata.uns['Supertype_colors'] = [color_map.get(s, '#333333') for s in supertypes]

# color by cell supertype — Allen Institute annotations
sc.pl.umap(adata, color='Supertype',
           title='Microglial supertypes  — Allen Institute annotations',
           save = '_supertype.png')


# color by cognitive status — disease grouping
sc.pl.umap(adata, color='Cognitive Status',
           title='UMAP by cognitive status',
           save = '_cognitive_status.png')

# color by Braak stage — continuous disease severity
sc.pl.umap(adata, color='Braak',
           title='UMAP by Braak stage',
           color_map='RdYlBu_r',
            save = '_braak_stage.png')

# color by severely affected donor flag
sc.pl.umap(adata, color='Severely Affected Donor',
           title='Severely affected donors',
           save = '_severely_affected_donor.png')
# Out:
# WARNING: saving figure to file ..\results\umap_supertype.png
# WARNING: saving figure to file ..\results\umap_cognitive_status.png
# WARNING: saving figure to file ..\results\umap_braak_stage.png
# WARNING: saving figure to file ..\results\umap_severely_affected_donor.png

# %%
# Cell 7 - Merge Neuropathology and Clinical Metadata

# Step 1: only keep meta columns that aren't already in adata.obs
meta_cols = [
    'Donor ID', 'Braak', 'CERAD score', 'Thal',
    'Overall AD neuropathological Change', 'APOE Genotype',
    'Age at Death', 'Sex', 'PMI', 'Last MMSE Score', 'LATE'
]

# filter to only new columns
new_meta_cols = ['Donor ID'] + [c for c in meta_cols[1:] 
                                 if c not in adata.obs.columns]
print("Meta cols to merge:", new_meta_cols)

# Step 2: neuropath columns
neuropath_cols = [
    'Donor ID',
    'percent Iba1 positive area_Grey matter',
    'number of activated Iba1 positive cells_Grey matter',
    'number of inactivated Iba1 positive cells_Grey matter',
    'number of Iba1 positive cells per area_Grey matter',
    'average Iba1 positive process length per cell_Grey matter',
    'percent AT8 positive area_Grey matter',
    'number of AT8 positive cells per area_Grey matter',
    'percent 6e10 positive area_Grey matter',
    'number of NeuN positive cells per area_Grey matter',
    'percent pTDP43 positive area_Grey matter',
    'ripa abeta42_Grey matter',
    'ripa pTau_Grey matter',
]

new_neuropath_cols = ['Donor ID'] + [c for c in neuropath_cols[1:] 
                                      if c not in adata.obs.columns]
print("Neuropath cols to merge:", new_neuropath_cols)

# Step 3: merge only new columns
if len(new_meta_cols) > 1:
    meta_slim = metadata[new_meta_cols].set_index('Donor ID')
    adata.obs = adata.obs.join(meta_slim, on='Donor ID')

neuropath_slim = neuropath[new_neuropath_cols].set_index('Donor ID')
adata.obs = adata.obs.join(neuropath_slim, on='Donor ID')

# Step 4: verify
print("\nSample merged values:")
check_cols = ['Donor ID', 'Braak', 'CERAD score', 
              'percent Iba1 positive area_Grey matter']
# only print cols that exist
check_cols = [c for c in check_cols if c in adata.obs.columns]
print(adata.obs[check_cols].head(5))

print("\nMissing values:")
print(adata.obs[check_cols].isnull().sum())
# Out:
# Meta cols to merge: ['Donor ID']
# Neuropath cols to merge: ['Donor ID', 'percent Iba1 positive area_Grey matter', 'number of activated Iba1 positive cells_Grey matter', 'number of inactivated Iba1 positive cells_Grey matter', 'number of Iba1 positive cells per area_Grey matter', 'average Iba1 positive process length per cell_Grey matter', 'percent AT8 positive area_Grey matter', 'number of AT8 positive cells per area_Grey matter', 'percent 6e10 positive area_Grey matter', 'number of NeuN positive cells per area_Grey matter', 'percent pTDP43 positive area_Grey matter', 'ripa abeta42_Grey matter', 'ripa pTau_Grey matter']
#
# Sample merged values:
#                                                   Donor ID    Braak  \
# exp_component_name
# AAAGAACTCCAACACA-L8HX_230330_23_E03-1266294882  H21.33.036  Braak V
# AACAACCTCTATTTCG-L8HX_230330_23_E03-1266294882  H21.33.036  Braak V
# AACCATGCACGGGTAA-L8HX_230330_23_E03-1266294882  H21.33.036  Braak V
# ...

# %%
print(adata.X[:5,:5])
print(adata.raw is None)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (5, 5)>
# True

# %%
# Cell 8 – Gene Set Scoring

# DAM signature human orthologs
# Mouse-specific symbols (H2-D1, Ccl6) removed where no clean 1-to-1 human ortholog exists
# Mouse symbol Lyz2 replaced with confirmed human ortholog LYZ
dam_genes = [
    'APOE',     # Apolipoprotein E; canonical DAM marker in both mouse and human (Keren-Shaul et al., 2017, Cell; Yin et al., 2017)
    'B2M',      # Beta-2-microglobulin; DAM1 stage marker, MHC class I component (Haage et al., 2024)
    'FTH1',     # Ferritin heavy chain 1; DAM1 iron metabolism marker (Keren-Shaul et al., 2017)
    'CSTB',     # Cystatin B; lysosomal protease inhibitor, DAM1 marker (Keren-Shaul et al., 2017)
    'LYZ',      # Lysozyme; human ortholog of mouse Lyz2 per MGI (https://www.informatics.jax.org/marker/MGI:96897, HGNC:6740)
    'CTSB',     # Cathepsin B; lysosomal protease upregulated in DAM (Keren-Shaul et al., 2017)
    'TYROBP',   # TYRO protein tyrosine kinase binding protein (DAP12); TREM2 co-receptor, AD risk gene (Lambert et al., 2013; Keren-Shaul et al., 2017)
    'TIMP2',    # Tissue inhibitor of metalloproteinases 2; DAM1 marker (Haage et al., 2024)
    'CTSD',     # Cathepsin D; lysosomal protease, AD risk factor (Lambert et al., 2013; Keren-Shaul et al., 2017)
    'CD9',      # Tetraspanin CD9; DAM2 stage marker (Keren-Shaul et al., 2017)
    'CD63',     # Tetraspanin CD63; lysosomal/late endosomal marker, DAM2 (Keren-Shaul et al., 2017)
    'SERPINE2', # Serpin family E member 2; DAM2 marker (Haage et al., 2024)
    'SPP1',     # Secreted phosphoprotein 1 (osteopontin); core DAM2 marker (Keren-Shaul et al., 2017; Krasemann et al., 2017)
    'CADM1',    # Cell adhesion molecule 1; DAM2 marker (Haage et al., 2024)
    'CD68',     # Macrosialin; classical activated microglia/macrophage marker (Keren-Shaul et al., 2017)
    'CTSZ',     # Cathepsin Z; lysosomal protease upregulated in DAM (Keren-Shaul et al., 2017)
    'AXL',      # AXL receptor tyrosine kinase; DAM2 marker, phagocytic receptor (Krasemann et al., 2017; Yin et al., 2017)
    'CLEC7A',   # C-type lectin domain family 7A (Dectin-1); canonical DAM2 marker (Keren-Shaul et al., 2017; Krasemann et al., 2017)
    'CTSA',     # Cathepsin A; lysosomal protease, DAM2 marker (Keren-Shaul et al., 2017)
    'CD52',     # CD52 antigen; lymphocyte/myeloid surface marker, DAM2 (Keren-Shaul et al., 2017)
    'CSF1',     # Colony stimulating factor 1; microglial proliferation/survival, DAM-associated (Keren-Shaul et al., 2017)
    'LPL',      # Lipoprotein lipase; canonical DAM2 lipid metabolism marker (Keren-Shaul et al., 2017)
    'CTSL',     # Cathepsin L; lysosomal protease (Keren-Shaul et al., 2017)
    'CST7',     # Cystatin F; DAM2 marker (Keren-Shaul et al., 2017)
    'ITGAX',    # Integrin alpha X (CD11c); DAM2 surface marker (Keren-Shaul et al., 2017)
    'GUSB',     # Beta-glucuronidase; lysosomal enzyme, DAM2 (Keren-Shaul et al., 2017)
    'HIF1A',    # Hypoxia inducible factor 1 alpha; metabolic stress response in DAM (Keren-Shaul et al., 2017)
]

# Homeostatic microglia signature genes
# Human gene symbols (uppercase). Original mouse-style symbols converted via MGI ortholog records.

# 7/28: Dropped TREM2 as it can be expressed in both homeo and DAM states
homeostatic_genes = [
    'SALL1',    # Spalt-like transcription factor 1; microglia identity gene (Buttgereit et al., 2016; Holtman et al., 2020)
    'HEXB',     # Hexosaminidase subunit beta; stable microglia marker even in disease (Masuda et al., 2020, Nature)
    'FCRLS',    # Fc receptor-like S; mouse microglia signature gene (Butovsky et al., 2014); note: limited human expression
    'CX3CR1',   # CX3C chemokine receptor 1; classical microglia marker (Hickman et al., 2013; Butovsky et al., 2014)
    'TMEM119',  # Transmembrane protein 119; specific microglia marker (Bennett et al., 2016; Hickman et al., 2013)
    'P2RY12',   # Purinergic receptor P2Y12; gold-standard homeostatic microglia marker (Butovsky et al., 2014; Hickman et al., 2013)
    'MERTK',    # MER proto-oncogene tyrosine kinase; phagocytic receptor in homeostatic microglia (Butovsky et al., 2014)
    'PROS1',    # Protein S; MERTK/AXL ligand (Butovsky et al., 2014)
    # SIGLECH removed: mouse-specific sensome gene with no direct human ortholog
    # GPR43 removed: was synonym for FFAR2; not part of canonical human homeostatic signature
]

# Case-insensitive filtering and remapping to exact casing in adata
var_names_upper = [g.upper() for g in adata.var_names]
upper_to_actual = {g.upper(): g for g in adata.var_names}

dam_genes_filtered = [upper_to_actual[g.upper()] for g in dam_genes if g.upper() in var_names_upper]
homeostatic_genes_filtered = [upper_to_actual[g.upper()] for g in homeostatic_genes if g.upper() in var_names_upper]

print("DAM genes found:", dam_genes_filtered)
print("Homeostatic genes found:", homeostatic_genes_filtered)

# score each cell
sc.tl.score_genes(adata, dam_genes_filtered, score_name='DAM_score')
sc.tl.score_genes(adata, homeostatic_genes_filtered, score_name='Homeostatic_score')

# visualize on UMAP
#sc.pl.umap(adata, color=['DAM_score', 'Homeostatic_score'],
#           color_map='RdYlBu_r', show=False)
# plt.savefig('../results/umap_gene_scores.png',
#             dpi=300, bbox_inches='tight', facecolor='white')
# plt.show()
# plt.close()
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (5, 5)>
# DAM genes found: ['APOE', 'B2M', 'FTH1', 'CSTB', 'LYZ', 'CTSB', 'TYROBP', 'TIMP2', 'CTSD', 'CD9', 'CD63', 'SERPINE2', 'SPP1', 'CADM1', 'CD68', 'CTSZ', 'AXL', 'CLEC7A', 'CTSA', 'CD52', 'CSF1', 'LPL', 'CTSL', 'CST7', 'ITGAX', 'GUSB', 'HIF1A']
# Homeostatic genes found: ['SALL1', 'HEXB', 'CX3CR1', 'TMEM119', 'TREM2', 'P2RY12', 'MERTK', 'PROS1']
# computing score 'DAM_score'
#     finished: added
#     'DAM_score', score of gene set (adata.obs).
#     499 total control genes are used. (0:00:12)
# computing score 'Homeostatic_score'
#     finished: added
#     'Homeostatic_score', score of gene set (adata.obs).
#     149 total control genes are used. (0:00:07)

# %%
# Cell 8B: compare supertype locations to DAM score zones
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sc.pl.umap(adata, color='Supertype', title='Supertypes', 
           show=False, ax=axes[0])
sc.pl.umap(adata, color='DAM_score', color_map='RdYlBu_r',
           title='DAM Score', show=False, ax=axes[1])
sc.pl.umap(adata, color='Homeostatic_score', color_map='RdYlBu_r',
           title='Homeostatic Score', show=False, ax=axes[2])

plt.tight_layout()
plt.savefig('../figures/umap_supertype_vs_scores.png',
            dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# %%
# Cell 8C - Quantify DAM and Homeostatic Score Patterns per Supertype (Donor-aware)

# 1. Donor-level aggregation per supertype
# First aggregate cells -> (donor, supertype) means, so each donor contributes one value per supertype
donor_supertype = adata.obs.groupby(['Donor ID', 'Supertype'], observed=True).agg(
    DAM_mean=('DAM_score', 'mean'),
    Homeostatic_mean=('Homeostatic_score', 'mean'),
    n_cells=('DAM_score', 'count')
).reset_index()

# Then collapse to supertype-level summary (mean across donors)
supertype_scores = donor_supertype.groupby('Supertype', observed=True).agg(
    DAM_mean=('DAM_mean', 'mean'),
    DAM_std=('DAM_mean', 'std'),
    Homeostatic_mean=('Homeostatic_mean', 'mean'),
    Homeostatic_std=('Homeostatic_mean', 'std'),
    n_donors=('Donor ID', 'nunique'),
    n_cells=('n_cells', 'sum')
).reset_index()

# FIX: use DIFFERENCE instead of ratio (ratios break with negative denominators)
supertype_scores['DAM_minus_Homeo'] = (
    supertype_scores['DAM_mean'] - supertype_scores['Homeostatic_mean']
)

supertype_scores = supertype_scores.sort_values('DAM_mean', ascending=False)

print("Supertype activation profile (donor-aggregated):")
print(supertype_scores[['Supertype', 'DAM_mean', 'Homeostatic_mean',
                         'DAM_minus_Homeo', 'n_donors', 'n_cells']].to_string(index=False))

# 2. Donor-level Mann-Whitney: each supertype vs all others
# Test on per-donor supertype means, not pooled cells
from statsmodels.stats.multitest import multipletests

global_mean = donor_supertype['DAM_mean'].mean()
print(f"\nGlobal mean DAM score (donor-aggregated): {global_mean:.4f}")
print(f"\nDonor-level Mann-Whitney U per supertype (vs other supertypes):")
print(f"{'Supertype':<25} {'DAM mean':>10} {'p-value':>10} {'p_adj':>10}")
print("-" * 65)

pvals, stypes_tested, means = [], [], []
for stype in supertype_scores['Supertype']:
    group = donor_supertype.loc[donor_supertype['Supertype'] == stype, 'DAM_mean']
    other = donor_supertype.loc[donor_supertype['Supertype'] != stype, 'DAM_mean']
    if len(group) < 3 or len(other) < 3:
        continue
    stat, p = stats.mannwhitneyu(group, other, alternative='two-sided')
    pvals.append(p)
    stypes_tested.append(stype)
    means.append(group.mean())

_, pvals_adj, _, _ = multipletests(pvals, method='fdr_bh')
for stype, m, p, padj in zip(stypes_tested, means, pvals, pvals_adj):
    print(f"{stype:<25} {m:>10.4f} {p:>10.2e} {padj:>10.2e}")

# 3. Figure: DAM vs Homeostatic (donor-aggregated)
subtype_colors = {
    'Micro-PVM_1':         '#2196F3',
    'Micro-PVM_2':         '#4CAF50',
    'Micro-PVM_2_1-SEAAD': '#F44336',
    'Micro-PVM_2_3-SEAAD': '#FF9800',
    'Micro-PVM_3-SEAAD':   '#9C27B0',
    'Micro-PVM_4-SEAAD':   '#E91E63',
    'Monocyte':            '#795548',
    'Lymphocyte':          '#607D8B',
}

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

colors = [subtype_colors.get(s, '#333333') for s in supertype_scores['Supertype']]
axes[0].barh(supertype_scores['Supertype'], supertype_scores['DAM_mean'],
             xerr=supertype_scores['DAM_std'], color=colors, alpha=0.85, capsize=4)
axes[0].axvline(global_mean, color='black', linestyle='--', linewidth=1.5,
                label=f'Global mean ({global_mean:.2f})')
axes[0].set_xlabel('Mean DAM Score (donor-aggregated)')
axes[0].set_title('DAM Score by Supertype')
axes[0].legend(fontsize=8)
axes[0].invert_yaxis()

homeo_sorted = supertype_scores.sort_values('Homeostatic_mean', ascending=False)
colors_h = [subtype_colors.get(s, '#333333') for s in homeo_sorted['Supertype']]
global_homeo = donor_supertype['Homeostatic_mean'].mean()
axes[1].barh(homeo_sorted['Supertype'], homeo_sorted['Homeostatic_mean'],
             xerr=homeo_sorted['Homeostatic_std'], color=colors_h, alpha=0.85, capsize=4)
axes[1].axvline(global_homeo, color='black', linestyle='--', linewidth=1.5,
                label=f'Global mean ({global_homeo:.2f})')
axes[1].set_xlabel('Mean Homeostatic Score (donor-aggregated)')
axes[1].set_title('Homeostatic Score by Supertype')
axes[1].legend(fontsize=8)
axes[1].invert_yaxis()

for _, row in supertype_scores.iterrows():
    color = subtype_colors.get(row['Supertype'], '#333333')
    is_seaad = 'SEAAD' in str(row['Supertype'])
    axes[2].scatter(row['Homeostatic_mean'], row['DAM_mean'],
                    color=color, s=row['n_donors']*30, alpha=0.85,
                    edgecolors='black' if is_seaad else 'none',
                    linewidth=1.5, zorder=3)
    axes[2].annotate(row['Supertype'].replace('Micro-PVM_', ''),
                     (row['Homeostatic_mean'], row['DAM_mean']),
                     fontsize=7, ha='left',
                     xytext=(4, 2), textcoords='offset points')

axes[2].axhline(global_mean, color='grey', linestyle='--', alpha=0.5)
axes[2].axvline(global_homeo, color='grey', linestyle='--', alpha=0.5)
axes[2].set_xlabel('Mean Homeostatic Score')
axes[2].set_ylabel('Mean DAM Score')
axes[2].set_title('DAM vs Homeostatic\n(size = donor count, outline = SEAAD subtype)')

plt.suptitle('Microglial Activation State Profiles by Supertype (Donor-Aggregated)',
             fontsize=14, y=1.02)
plt.tight_layout()
plt.savefig('../figures/supertype_activation_profiles.png',
            dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# 4. SEAAD vs canonical: consistent donor-level test
# Use donor-level supertype means, restricted to microglial supertypes
micro_only = donor_supertype[donor_supertype['Supertype'].str.contains('Micro')].copy()
micro_only['is_SEAAD'] = micro_only['Supertype'].str.contains('SEAAD')

seaad_vals     = micro_only.loc[micro_only['is_SEAAD'],  'DAM_mean']
canonical_vals = micro_only.loc[~micro_only['is_SEAAD'], 'DAM_mean']

print(f"\n── SEAAD vs Canonical Microglia (Donor-Aggregated DAM means) ──")
print(f"SEAAD subtypes:     mean={seaad_vals.mean():.4f}, n_obs={len(seaad_vals)}")
print(f"Canonical subtypes: mean={canonical_vals.mean():.4f}, n_obs={len(canonical_vals)}")

# Two-sided test, donor-aggregated values
stat, p_two = stats.mannwhitneyu(seaad_vals, canonical_vals, alternative='two-sided')
print(f"Two-sided Mann-Whitney U: p={p_two:.4e}")
direction = "higher" if seaad_vals.mean() > canonical_vals.mean() else "lower"
print(f"Direction: SEAAD subtypes show {direction} DAM scores than canonical "
      f"({'significant' if p_two < 0.05 else 'not significant'})")
# Out:
# Supertype activation profile (donor-aggregated):
#           Supertype  DAM_mean  Homeostatic_mean  DAM_minus_Homeo  n_donors  n_cells
#   Micro-PVM_4-SEAAD  1.087213         -0.211264         1.298477        68     1767
#   Micro-PVM_3-SEAAD  0.800151          0.046087         0.754064        84    29805
#            Monocyte  0.696486         -0.583930         1.280416        25       42
#         Micro-PVM_2  0.690953          0.223180         0.467773        84   141248
#         Micro-PVM_1  0.576826         -0.298268         0.875095        84     7909
# Micro-PVM_2_3-SEAAD  0.494069          0.086729         0.407340        84    53815
# Micro-PVM_2_1-SEAAD  0.460658         -0.149140         0.609798        66     1458
#          Lymphocyte  0.027538         -0.761076         0.788614        84     4607
#
# Global mean DAM score (donor-aggregated): 0.5860
#
# Donor-level Mann-Whitney U per supertype (vs other supertypes):
# ...

# %%
# Cell 9 - Subtype Composition Analysis
# calculate proportion of each supertype per donor
composition = (adata.obs
    .groupby(['Donor ID', 'Supertype'],observed=True)
    .size()
    .unstack(fill_value=0))

composition_pct = composition.div(composition.sum(axis=1), axis=0) * 100

# attach braak stage per donor
donor_meta = adata.obs.drop_duplicates('Donor ID').set_index('Donor ID')
composition_pct['Braak'] = donor_meta['Braak']
composition_pct['Cognitive Status'] = donor_meta['Cognitive Status']

# melt for seaborn
comp_melt = composition_pct.reset_index().melt(
    id_vars=['Donor ID', 'Braak', 'Cognitive Status'],
    var_name='Supertype',
    value_name='Proportion'
)

# focus on SEAAD subtypes specifically
seaad_subtypes = [s for s in adata.obs['Supertype'].unique() if 'SEAAD' in str(s)]
comp_seaad = comp_melt[comp_melt['Supertype'].isin(seaad_subtypes)]

fig, ax = plt.subplots(figsize=(12, 5))
sns.boxplot(data=comp_seaad, x='Braak', y='Proportion',
            hue='Supertype', ax=ax,
            palette=['#F44336', '#FF9800', '#9C27B0', '#E91E63'])
ax.set_title('SEAAD microglial subtype abundance by Braak stage')
ax.set_ylabel('% of microglia per donor')
ax.set_xlabel('Braak Stage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig('../figures/composition_braak.png',
            dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# %%
# Cell 10 - Correlation Analysis: DAM score vs Neuropathological Variables (Donor Level)
# Ordinal encoding
braak_order = {'Braak 0': 0, 'Braak II': 2, 'Braak III': 3, 'Braak IV': 4, 'Braak V': 5, 'Braak VI': 6}
cerad_order = {'Absent': 0, 'Sparse': 1, 'Moderate': 2, 'Frequent': 3}
thal_order  = {'Thal 0': 0, 'Thal 1': 1, 'Thal 2': 2, 'Thal 3': 3, 'Thal 4': 4, 'Thal 5': 5}
adnc_order  = {'Not AD': 0, 'Low': 1, 'Intermediate': 2, 'High': 3}
cog_order   = {'No dementia': 0, 'Dementia': 1}

adata.obs['Braak_num']     = adata.obs['Braak'].map(braak_order)
adata.obs['CERAD_num']     = adata.obs['CERAD score'].map(cerad_order)
adata.obs['Thal_num']      = adata.obs['Thal'].map(thal_order)
adata.obs['ADNC_num']      = adata.obs['Overall AD neuropathological Change'].map(adnc_order)
adata.obs['CogStatus_num'] = adata.obs['Cognitive Status'].map(cog_order)

# Aggregate to donor level
donor_df = adata.obs.groupby('Donor ID').agg(
    DAM_score         = ('DAM_score', 'mean'),
    Homeostatic_score = ('Homeostatic_score', 'mean'),
    Braak_num         = ('Braak_num', 'first'),
    CERAD_num         = ('CERAD_num', 'first'),
    Thal_num          = ('Thal_num', 'first'),
    ADNC_num          = ('ADNC_num', 'first'),
    CogStatus_num     = ('CogStatus_num', 'first'),
    Age_at_Death      = ('Age at Death', 'first'),
).reset_index()

print(f"Number of donors: {len(donor_df)}")
print(donor_df.head())

# Spearman correlations
correlations = {}
for col, label in [('Braak_num',     'Braak Stage'),
                   ('CERAD_num',     'CERAD Score'),
                   ('Thal_num',      'Thal Phase'),
                   ('ADNC_num',      'Overall AD Neuropathological Change'),
                   ('CogStatus_num', 'Cognitive Status'),
                   ('Age_at_Death',  'Age at Death')]:
    df_tmp = donor_df[['DAM_score', col]].dropna()
    rho, pval = stats.spearmanr(df_tmp['DAM_score'], df_tmp[col])
    correlations[label] = {'rho': round(rho, 4), 'p': round(pval, 4)}

corr_df = pd.DataFrame(correlations).T
corr_df['significant'] = corr_df['p'] < 0.05
print("\nCorrelation results:")
print(corr_df)

# Plot: correlation bar chart
fig, ax = plt.subplots(figsize=(8, 5))
colors = ['steelblue' if s else 'lightgrey' for s in corr_df['significant']]
ax.barh(corr_df.index, corr_df['rho'], color=colors)
ax.axvline(0, color='black', linewidth=0.8)
ax.set_xlabel("Spearman's rho")
ax.set_title("DAM Score Correlation with Neuropathological Variables\n(Donor Level)")
plt.tight_layout()
plt.savefig('../figures/DAM_correlations_donor_level.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# Plot: DAM score by Braak stage (boxplot)
donor_df['Braak'] = adata.obs.groupby('Donor ID')['Braak'].first().values
fig, ax = plt.subplots(figsize=(8, 5))
braak_order_list = ['Braak 0', 'Braak II', 'Braak III', 'Braak IV', 'Braak V', 'Braak VI']
sns.boxplot(data=donor_df, x='Braak', y='DAM_score', order=braak_order_list,
            palette='Blues', ax=ax)
ax.set_title('DAM Score by Braak Stage (Donor Level)')
ax.set_xlabel('Braak Stage')
ax.set_ylabel('Mean DAM Score per Donor')
plt.tight_layout()
plt.savefig('../figures/DAM_by_Braak_donor_level.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()
# Out:
# C:\Users\billn\AppData\Local\Temp\ipykernel_18128\61098948.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   donor_df = adata.obs.groupby('Donor ID').agg(
# Number of donors: 84
#      Donor ID  DAM_score  Homeostatic_score Braak_num CERAD_num Thal_num  \
# 0  H19.33.004   0.561650           0.137502         4         0        0
# 1  H20.33.001   0.689743           0.154911         4         1        2
# 2  H20.33.002   0.606195           0.080936         4         0        0
# 3  H20.33.004   0.796284          -0.252823         5         3        5
# 4  H20.33.005   0.439176           0.240999         4         2        3
#
#   ADNC_num CogStatus_num  Age_at_Death
# 0        0             0          80.0
# 1        1             0          82.0
# 2        0             0          97.0
# ...

# %%
# Cell 11 - APOE4 Subgroup Analysis: Carriers vs Non-carriers (Donor Level)
from scipy.stats import mannwhitneyu

# Define APOE4 carrier status
apoe4_carriers    = ['3/4', '4/4', '2/4']
apoe4_noncarriers = ['3/3', '2/3', '2/2']

# Clean up any leftover columns from previous runs before merging
for col in ['APOE_Genotype', 'APOE_Genotype_x', 'APOE_Genotype_y', 'APOE4_status']:
    if col in donor_df.columns:
        donor_df = donor_df.drop(columns=[col])

# Merge APOE genotype onto donor_df by Donor ID
apoe_map = adata.obs.groupby('Donor ID', observed=True)['APOE Genotype'].first().reset_index()
apoe_map.columns = ['Donor ID', 'APOE_Genotype']
donor_df = donor_df.merge(apoe_map, on='Donor ID', how='left')

# Classify carrier status
donor_df['APOE4_status'] = donor_df['APOE_Genotype'].apply(
    lambda x: 'Carrier' if x in apoe4_carriers else ('Non-carrier' if x in apoe4_noncarriers else np.nan)
)

print(f"APOE4 Carriers:     {(donor_df['APOE4_status'] == 'Carrier').sum()} donors")
print(f"APOE4 Non-carriers: {(donor_df['APOE4_status'] == 'Non-carrier').sum()} donors")

# Mann-Whitney U test at donor level (treats each donor as one independent observation)
for score in ['DAM_score', 'Homeostatic_score']:
    carriers    = donor_df.loc[donor_df['APOE4_status'] == 'Carrier', score].dropna()
    noncarriers = donor_df.loc[donor_df['APOE4_status'] == 'Non-carrier', score].dropna()
    u_stat, pval = mannwhitneyu(carriers, noncarriers, alternative='two-sided')
    print(f"\n{score}:")
    print(f"  U = {u_stat:.1f}, p = {pval:.4f}")
    print(f"  Carrier median     = {carriers.median():.4f} (n={len(carriers)})")
    print(f"  Non-carrier median = {noncarriers.median():.4f} (n={len(noncarriers)})")

# Plot: DAM and Homeostatic scores by APOE4 status
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
for ax, score, title in zip(axes,
                             ['DAM_score', 'Homeostatic_score'],
                             ['DAM Score', 'Homeostatic Score']):
    sns.boxplot(data=donor_df, x='APOE4_status', y=score,
                order=['Non-carrier', 'Carrier'],
                palette={'Non-carrier': 'steelblue', 'Carrier': 'tomato'}, ax=ax)
    ax.set_title(f'{title} by APOE4 Status\n(Donor Level, n={len(donor_df.dropna(subset=[score]))})')
    ax.set_xlabel('APOE4 Status')
    ax.set_ylabel(f'Mean {title} per Donor')

plt.tight_layout()
plt.savefig('../figures/APOE4_scores_donor_level.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# Plot: DAM score by all APOE genotypes
fig, ax = plt.subplots(figsize=(9, 5))
geno_order = ['2/2', '2/3', '3/3', '2/4', '3/4', '4/4']
sns.boxplot(data=donor_df, x='APOE_Genotype', y='DAM_score',
            order=geno_order, palette='coolwarm', ax=ax)
ax.set_title('DAM Score by APOE Genotype\n(Donor Level)')
ax.set_xlabel('APOE Genotype')
ax.set_ylabel('Mean DAM Score per Donor')

# Annotate n per group so small subgroups (2/2, 2/4) are clearly flagged
for i, geno in enumerate(geno_order):
    n = (donor_df['APOE_Genotype'] == geno).sum()
    ax.text(i, ax.get_ylim()[0], f'n={n}', ha='center', va='bottom', fontsize=8, color='black')

plt.tight_layout()
plt.savefig('../figures/DAM_by_APOE_genotype_donor_level.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()
# Out:
# APOE4 Carriers:     25 donors
# APOE4 Non-carriers: 59 donors
#
# DAM_score:
#   U = 905.0, p = 0.1023
#   Carrier median     = 0.6491 (n=25)
#   Non-carrier median = 0.6050 (n=59)
#
# Homeostatic_score:
#   U = 675.0, p = 0.5441
#   Carrier median     = 0.0842 (n=25)
#   Non-carrier median = 0.1519 (n=59)
# C:\Users\billn\AppData\Local\Temp\ipykernel_18128\2870431671.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=donor_df, x='APOE4_status', y=score,
# C:\Users\billn\AppData\Local\Temp\ipykernel_18128\2870431671.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=donor_df, x='APOE4_status', y=score,
# ...

# %%
# Cell 12 - Differential Expression Analysis (Pseudobulk, Donor Level)
from scipy.stats import mannwhitneyu
from scipy.sparse import issparse
from statsmodels.stats.multitest import multipletests

os.makedirs('../figures', exist_ok=True)
os.makedirs('../results', exist_ok=True)

# Split donors into DAM-high and DAM-low based on median DAM score
# Note: this grouping is derived from the same expression data used downstream,
# so DE results should be treated as exploratory rather than independent validation
dam_median = donor_df['DAM_score'].median()
donor_df['DAM_group'] = donor_df['DAM_score'].apply(
    lambda x: 'DAM-high' if x >= dam_median else 'DAM-low'
)
dam_group_map = donor_df.set_index('Donor ID')['DAM_group'].to_dict()
adata.obs['DAM_group'] = adata.obs['Donor ID'].map(dam_group_map)

print(f"DAM-high donors: {(donor_df['DAM_group'] == 'DAM-high').sum()}")
print(f"DAM-low donors:  {(donor_df['DAM_group'] == 'DAM-low').sum()}")

# Build pseudobulk matrix using raw UMI counts (not log-normalized adata.X)
# Summing raw integer counts per donor is the statistically valid pseudobulk construction
print("\nBuilding pseudobulk matrix from raw UMI counts...")
donors     = donor_df['Donor ID'].tolist()
gene_names = adata.var_names.tolist()
pb_matrix  = pd.DataFrame(index=donors, columns=gene_names, dtype=float)

for donor in donors:
    mask = adata.obs['Donor ID'] == donor
    X    = adata[mask].layers['UMIs']
    if issparse(X):
        X = X.toarray()
    pb_matrix.loc[donor] = X.sum(axis=0)

print(f"Pseudobulk matrix shape: {pb_matrix.shape}")

# CPM normalize then log1p transform
pb_matrix = pb_matrix.div(pb_matrix.sum(axis=1), axis=0) * 1e6
pb_matrix = np.log1p(pb_matrix)

# Assign DAM group
pb_matrix['DAM_group'] = pb_matrix.index.map(dam_group_map)
high_donors = pb_matrix[pb_matrix['DAM_group'] == 'DAM-high'].drop(columns='DAM_group')
low_donors  = pb_matrix[pb_matrix['DAM_group'] == 'DAM-low'].drop(columns='DAM_group')

# Mann-Whitney U per gene at donor level
# Test statistic is mean difference of log1p(CPM), not true log2 fold change
print("Running differential expression...")
results = []
for gene in gene_names:
    u_stat, pval = mannwhitneyu(high_donors[gene], low_donors[gene], alternative='two-sided')
    mean_diff = high_donors[gene].mean() - low_donors[gene].mean()
    results.append({'gene': gene, 'mean_diff_log1p_CPM': mean_diff, 'pval': pval})

de_results = pd.DataFrame(results)

# Benjamini-Hochberg correction
_, pval_adj, _, _ = multipletests(de_results['pval'], method='fdr_bh')
de_results['pval_adj'] = pval_adj
de_results = de_results.sort_values('pval_adj')

# Filter significant DEGs
sig_up   = de_results[(de_results['pval_adj'] < 0.05) & (de_results['mean_diff_log1p_CPM'] >  0.5)]
sig_down = de_results[(de_results['pval_adj'] < 0.05) & (de_results['mean_diff_log1p_CPM'] < -0.5)]

print(f"\nSignificantly upregulated genes:   {len(sig_up)}")
print(f"Significantly downregulated genes: {len(sig_down)}")
print("\nTop 10 upregulated:")
print(sig_up.head(10)[['gene', 'mean_diff_log1p_CPM', 'pval_adj']])
print("\nTop 10 downregulated:")
print(sig_down.head(10)[['gene', 'mean_diff_log1p_CPM', 'pval_adj']])

# Check overlap with DAM and homeostatic gene signatures
dam_overlap         = sig_up[sig_up['gene'].str.upper().isin([g.upper() for g in dam_genes])]
homeostatic_overlap = sig_down[sig_down['gene'].str.upper().isin([g.upper() for g in homeostatic_genes])]

print(f"\nDAM signature genes in upregulated:           {dam_overlap['gene'].tolist()}")
print(f"Homeostatic signature genes in downregulated:  {homeostatic_overlap['gene'].tolist()}")

# Volcano plot
fig, ax = plt.subplots(figsize=(9, 6))
de_results['color'] = 'lightgrey'
de_results.loc[(de_results['pval_adj'] < 0.05) & (de_results['mean_diff_log1p_CPM'] >  0.5), 'color'] = 'tomato'
de_results.loc[(de_results['pval_adj'] < 0.05) & (de_results['mean_diff_log1p_CPM'] < -0.5), 'color'] = 'steelblue'
ax.scatter(de_results['mean_diff_log1p_CPM'], -np.log10(de_results['pval_adj'] + 1e-300),
           c=de_results['color'], alpha=0.5, s=10)

# Label top hits
label_genes = pd.concat([sig_up.head(10), sig_down.head(10)])
for _, row in label_genes.iterrows():
    ax.annotate(row['gene'],
                xy=(row['mean_diff_log1p_CPM'], -np.log10(row['pval_adj'] + 1e-300)),
                fontsize=7, alpha=0.8)

ax.axvline(x=0.5,  color='black', linestyle='--', linewidth=0.8)
ax.axvline(x=-0.5, color='black', linestyle='--', linewidth=0.8)
ax.axhline(y=-np.log10(0.05), color='black', linestyle='--', linewidth=0.8)
ax.set_xlabel('Mean Difference of log1p(CPM) (DAM-high vs DAM-low)')
ax.set_ylabel('-log10(adjusted p-value)')
ax.set_title('Differential Expression: DAM-high vs DAM-low Donors\n(Pseudobulk, Donor Level)')

from matplotlib.lines import Line2D
legend_elements = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor='tomato',    markersize=8, label='Upregulated (DAM-high)'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='steelblue', markersize=8, label='Downregulated (DAM-high)'),
    Line2D([0], [0], marker='o', color='w', markerfacecolor='lightgrey', markersize=8, label='Not significant'),
]
ax.legend(handles=legend_elements)
plt.tight_layout()
plt.savefig('../figures/volcano_DE.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()
# Out:
# DAM-high donors: 42
# DAM-low donors:  42
#
# Building pseudobulk matrix from raw UMI counts...
# Pseudobulk matrix shape: (84, 36601)
# Running differential expression...
#
# Significantly upregulated genes:   46
# Significantly downregulated genes: 23
#
# Top 10 upregulated:
#              gene  mean_diff_log1p_CPM  pval_adj
# 32239        APOE             0.537863  0.000009
# 32372        EMP3             0.502087  0.000012
# 29967   LINC00482             0.615716  0.000017
# 2066       S100A6             0.534071  0.000033
# 30029     SLC16A3             0.516250  0.000056
# 32496  AC020909.2             0.674587  0.000210
# 34989      LGALS1             0.532446  0.000215
# 18970       CD151             0.579750  0.000232
# 11079     PRELID1             0.507702  0.000306
# 32335       C5AR1             0.549211  0.000312
#
# Top 10 downregulated:
#              gene  mean_diff_log1p_CPM  pval_adj
# 26321  AC009432.2            -1.203350  0.000670
# ...
