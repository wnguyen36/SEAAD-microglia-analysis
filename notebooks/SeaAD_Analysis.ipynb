# %%
# Cell 1 — imports
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import spearmanr, kruskal, wilcoxon, mannwhitneyu, rankdata
from statsmodels.stats.multitest import multipletests
import scipy.sparse as sp
import sys

import os
os.makedirs('../results', exist_ok=True)

sys.path.append('..')

sc.settings.verbosity = 3
sc.settings.figdir = '../results/'

# %%
# Cell 2 - Load Data
adata = sc.read_h5ad('../data/SEAAD_microglia.h5ad')
print("Microglia dataset loaded") 
print(adata)

metadata = pd.read_excel('../data/SEAAD_donor_metadata.xlsx')
print("Clinical columns:")
print(metadata.columns.tolist())

neuropath = pd.read_csv('../data/SEAAD_neuropathology.csv')
print("Neuropathology columns:")
print(neuropath.columns.tolist())

print("\n--- donor ID column in adata.obs ---")
donor_cols = [c for c in adata.obs.columns if any(x in c.lower() for x in ['donor', 'external', 'specimen'])]
print(donor_cols)
print(adata.obs[donor_cols].head(5))
# Out:
# Microglia dataset loaded
# AnnData object with n_obs × n_vars = 240651 × 36601
# ...

# %%
# Cell 3 - Print labels at donor level
 
 
SEP = "=" * 78
print(SEP); print("COHORT DESCRIPTION (donor level)"); print(SEP)
 
KEY_CLINICAL = ["Cognitive Status", "Braak", "CERAD score",
                "Overall AD neuropathological Change", "Thal",
                "APOE Genotype", "Severely Affected Donor", "Sex"]
 
donors = adata.obs.drop_duplicates("Donor ID").set_index("Donor ID")
print(f"donors: {len(donors)}   nuclei: {adata.n_obs:,}")
print(f"nuclei per donor: min={adata.obs['Donor ID'].value_counts().min():,} "
      f"median={adata.obs['Donor ID'].value_counts().median():,.0f} "
      f"max={adata.obs['Donor ID'].value_counts().max():,}")
 
for col in KEY_CLINICAL:
    if col not in donors.columns:
        print(f"\n{col}: NOT FOUND")
        continue
    vc = donors[col].value_counts(dropna=False)
    pct = 100 * vc / len(donors)
    print(f"\n{col}:")
    for lvl, n in vc.items():
        print(f"  {str(lvl):<28} {n:>3} donors ({pct[lvl]:4.1f}%)")
 
for col in ["Age at Death", "PMI", "RIN", "Years of education"]:
    if col in donors.columns:
        v = pd.to_numeric(donors[col], errors="coerce").dropna()
        if len(v):
            print(f"\n{col}: median={v.median():.1f}  "
                  f"IQR={v.quantile(.25):.1f}-{v.quantile(.75):.1f}  "
                  f"range={v.min():.1f}-{v.max():.1f}  (n={len(v)})")
 
# show how misleading the nucleus-level version was
print("\n" + "-" * 78)
print("nucleus-level vs donor-level, for comparison:")
for col in ["Cognitive Status", "Braak"]:
    if col in adata.obs.columns:
        n_lvl = adata.obs[col].value_counts(normalize=True) * 100
        d_lvl = donors[col].value_counts(normalize=True) * 100
        print(f"\n{col}:")
        for lvl in d_lvl.index:
            print(f"  {str(lvl):<20} nuclei {n_lvl.get(lvl,0):5.1f}%   "
                  f"donors {d_lvl.get(lvl,0):5.1f}%")
# Out:
# ...
# COHORT DESCRIPTION (donor level)
# ...
# donors: 84   nuclei: 240,651
# nuclei per donor: min=512 median=2,514 max=7,284
#
# Cognitive Status:
#   Dementia                      42 donors (50.0%)
#   No dementia                   42 donors (50.0%)
#
# Braak:
#   Braak V                       34 donors (40.5%)
#   Braak IV                      23 donors (27.4%)
#   Braak VI                      15 donors (17.9%)
#   Braak III                      6 donors ( 7.1%)
#   Braak II                       4 donors ( 4.8%)
#   Braak 0                        2 donors ( 2.4%)
#
# CERAD score:
#   Frequent                      30 donors (35.7%)
#   Moderate                      26 donors (31.0%)
#   Absent                        16 donors (19.0%)
#   Sparse                        12 donors (14.3%)
#
# Overall AD neuropathological Change:
#   High                          42 donors (50.0%)
#   Intermediate                  21 donors (25.0%)
#   Low                           12 donors (14.3%)
# ...

# %%
# Cell 4 - Inspect Existing Cell Type Annotations

print("Subclass labels:")
print(adata.obs['Subclass'].value_counts())

print("\nSupertype labels:")
print(adata.obs['Supertype'].value_counts())

print("\nClass labels:")
print(adata.obs['Class'].value_counts())
# Out:
# Subclass labels:
# Subclass
# Microglia-PVM    240651
# Name: count, dtype: int64
#
# Supertype labels:
# Supertype
# Micro-PVM_2            141248
# Micro-PVM_2_3-SEAAD     53815
# Micro-PVM_3-SEAAD       29805
# Micro-PVM_1              7909
# Lymphocyte               4607
# Micro-PVM_4-SEAAD        1767
# Micro-PVM_2_1-SEAAD      1458
# Monocyte                   42
# Name: count, dtype: int64
#
# Class labels:
# Class
# Non-neuronal and Non-neural    240651
# Name: count, dtype: int64

# %%
# Cell 4B - Filter out Monocytes and Lymphocytes

KEEP_SUPERTYPE = [
    "Micro-PVM_1",
    "Micro-PVM_2",
    "Micro-PVM_2_1-SEAAD",
    "Micro-PVM_2_3-SEAAD",
    "Micro-PVM_3-SEAAD",
    "Micro-PVM_4-SEAAD",
]

keep_mask = adata.obs["Supertype"].astype(str).isin(KEEP_SUPERTYPE).values

present = set(adata.obs["Supertype"].astype(str).unique())
missing = [c for c in KEEP_SUPERTYPE if c not in present]
assert not missing, f"labels not found: {missing}\nAvailable: {sorted(present)}"

# characterise contamination BEFORE removing it
n_drop = int((~keep_mask).sum())
print(f"removing {n_drop:,} nuclei ({100*n_drop/adata.n_obs:.2f}%)")
print(adata.obs.loc[~keep_mask, "Supertype"].value_counts().to_string())

contam = pd.Series(~keep_mask, index=adata.obs["Donor ID"].values).groupby(level=0).mean()
print(f"per-donor contamination: min={contam.min():.4f} "
      f"median={contam.median():.4f} max={contam.max():.4f}")

# does contamination track pathology?
BRAAK_ORDER = {"Braak 0":0,"Braak I":1,"Braak II":2,"Braak III":3,
               "Braak IV":4,"Braak V":5,"Braak VI":6}
dm = adata.obs.drop_duplicates("Donor ID").set_index("Donor ID")
braak = dm["Braak"].astype(str).map(BRAAK_ORDER)
contam.index = contam.index.astype(str); braak.index = braak.index.astype(str)
d = pd.concat([contam, braak], axis=1).dropna()
rho, p = spearmanr(d.iloc[:,0], d.iloc[:,1])
print(f"contamination vs Braak: rho={rho:+.3f} p={p:.3f}")

adata = adata[keep_mask].copy()
print(f"-> {adata.n_obs:,} nuclei, {adata.obs['Donor ID'].nunique()} donors")
# Out:
# removing 4,649 nuclei (1.93%)
# Supertype
# Lymphocyte             4607
# Monocyte                 42
# Micro-PVM_2               0
# Micro-PVM_1               0
# Micro-PVM_2_1-SEAAD       0
# Micro-PVM_2_3-SEAAD       0
# Micro-PVM_3-SEAAD         0
# Micro-PVM_4-SEAAD         0
# per-donor contamination: min=0.0035 median=0.0153 max=0.2035
# contamination vs Braak: rho=+0.237 p=0.030
# C:\Users\billn\AppData\Local\Temp\ipykernel_21232\2687679829.py:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contam = pd.Series(~keep_mask, index=adata.obs["Donor ID"].values).groupby(level=0).mean()
# -> 236,002 nuclei, 84 donors

# %%
# Cell 5 - Check normalization

# Is layers['UMIs'] actually raw counts?
U = adata.layers['UMIs'][:1000].toarray()
print("integer-valued:", np.allclose(U, np.round(U)))

# Does .X back-transform to a constant row sum? (= normalize_total ran)
row_sums = np.asarray(adata.X[:1000].expm1().sum(axis=1)).ravel()
print("row sum mean:", row_sums.mean(), "std:", row_sums.std())

# Does .X reconstruct exactly from UMIs at that target?
i = 0
x = adata.X[i].toarray().ravel()
u = adata.layers['UMIs'][i].toarray().ravel()
recon = np.log1p(u / u.sum() * 100_000)
print("max diff:", np.abs(recon - x).max())
# Out:
# integer-valued: True
# row sum mean: 100000.0 std: 2.175499159453619e-11
# max diff: 8.881784197001252e-16

# %%
# Cell 6 - Visualize existing UMAP embeddings colored by clinical variables

# fix supertype colors
supertypes = adata.obs['Supertype'].cat.categories.tolist()
color_map = {
    'Micro-PVM_1':         '#2196F3',  # blue
    'Micro-PVM_2':         '#4CAF50',  # green
    'Micro-PVM_2_1-SEAAD': '#F44336',  # red
    'Micro-PVM_2_3-SEAAD': '#FF9800',  # orange
    'Micro-PVM_3-SEAAD':   '#9C27B0',  # purple
    'Micro-PVM_4-SEAAD':   '#E91E63',  # pink
    'Monocyte':            '#795548',  # brown
    'Lymphocyte':          '#607D8B',  # grey
}
adata.uns['Supertype_colors'] = [color_map.get(s, '#333333') for s in supertypes]

# color by cell supertype — Allen Institute annotations
sc.pl.umap(adata, color='Supertype',
           title='Microglial supertypes  — Allen Institute annotations',
           save = '_supertype.png')


# color by cognitive status — disease grouping
sc.pl.umap(adata, color='Cognitive Status',
           title='UMAP by cognitive status',
           save = '_cognitive_status.png')

# color by Braak stage — continuous disease severity
sc.pl.umap(adata, color='Braak',
           title='UMAP by Braak stage',
           color_map='RdYlBu_r',
            save = '_braak_stage.png')

# color by severely affected donor flag
sc.pl.umap(adata, color='Severely Affected Donor',
           title='Severely affected donors',
           save = '_severely_affected_donor.png')
# Out:
# WARNING: saving figure to file ..\results\umap_supertype.png
# WARNING: saving figure to file ..\results\umap_cognitive_status.png
# WARNING: saving figure to file ..\results\umap_braak_stage.png
# WARNING: saving figure to file ..\results\umap_severely_affected_donor.png

# %%
# Cell 6B - Region coverage and then diagnose whether to restrict to MTG or not
 
 
print("\n" + SEP); print("REGION COVERAGE"); print(SEP)
 
REGION = "Brain Region"
ct = pd.crosstab(adata.obs["Donor ID"], adata.obs[REGION])
frac = (ct.T / ct.sum(axis=1)).T
 
print(f"donors: {ct.shape[0]}   regions: {ct.shape[1]}\n")
summary = pd.DataFrame({
    "total_nuclei": ct.sum(),
    "mean_frac": frac.mean(),
    "sd_frac": frac.std(),
    "min_frac": frac.min(),
    "max_frac": frac.max(),
    "donors_with_zero": (ct == 0).sum(),
}).sort_values("total_nuclei", ascending=False)
print(summary.round(4).to_string())
 
print(f"\nregions per donor: min={(ct > 0).sum(1).min()} "
      f"median={(ct > 0).sum(1).median():.0f} max={(ct > 0).sum(1).max()}")
 
# is regional composition itself related to pathology?
BRAAK_ORDER = {"Braak 0": 0, "Braak I": 1, "Braak II": 2, "Braak III": 3,
               "Braak IV": 4, "Braak V": 5, "Braak VI": 6}
dm = adata.obs.drop_duplicates("Donor ID").set_index("Donor ID")
braak_num = dm["Braak"].astype(str).map(BRAAK_ORDER).reindex(frac.index)
 
print("\nregional fraction vs Braak (a significant result means regional")
print("composition is confounded with pathology):")
for r in frac.columns:
    d = pd.concat([frac[r], braak_num], axis=1).dropna()
    rho, p = spearmanr(d.iloc[:, 0], d.iloc[:, 1])
    flag = "  <-- CONFOUND" if p < 0.05 else ""
    print(f"  {r:<6} rho={rho:+.3f}  p={p:.3f}{flag}")
 
# --- MTG viability: the cleanest fix, since neuropathology is MTG-only ---
TARGET_REGION = "MTG"
print(f"\n{'-'*78}\nCAN THE ANALYSIS BE RESTRICTED TO {TARGET_REGION}?")
if TARGET_REGION in ct.columns:
    mtg = ct[TARGET_REGION]
    print(f"  nuclei in {TARGET_REGION:<4}        : {mtg.sum():,}")
    print(f"  donors with any      : {(mtg > 0).sum()} / {len(mtg)}")
    for thr in (20, 50, 100, 200):
        print(f"  donors with >= {thr:<4}    : {(mtg >= thr).sum()}")
    print(f"  nuclei per donor     : median={mtg[mtg>0].median():,.0f} "
          f"range={mtg[mtg>0].min():,.0f}-{mtg.max():,.0f}")
    lost = (mtg < 50).sum()
# Out:
# ...
# REGION COVERAGE
# ...
# donors: 84   regions: 1
#
#               total_nuclei  mean_frac  sd_frac  min_frac  max_frac  donors_with_zero
# Brain Region
# MTG                  35907        1.0      0.0       1.0       1.0                 0
#
# regions per donor: min=1 median=1 max=1
#
# regional fraction vs Braak (a significant result means regional
# composition is confounded with pathology):
#   MTG    rho=+nan  p=nan
#
# ------------------------------------------------------------------------------
# CAN THE ANALYSIS BE RESTRICTED TO MTG?
#   nuclei in MTG         : 35,907
#   donors with any      : 84 / 84
#   donors with >= 20      : 84
#   donors with >= 50      : 84
#   donors with >= 100     : 82
#   donors with >= 200     : 73
#   nuclei per donor     : median=376 range=63-1,034
# C:\Users\billn\AppData\Local\Temp\ipykernel_21232\1498799710.py:34: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# ...

# %%
# Cell 6C - Decision: Restrict to MTG
before_n, before_d = adata.n_obs, adata.obs['Donor ID'].nunique()
adata = adata[adata.obs['Brain Region'] == 'MTG'].copy()

print(f"nuclei : {before_n:,} -> {adata.n_obs:,}")
print(f"donors : {before_d} -> {adata.obs['Donor ID'].nunique()}")

cpd = adata.obs['Donor ID'].value_counts()
print(f"nuclei per donor: min={cpd.min()} median={cpd.median():.0f} max={cpd.max()}")
assert adata.obs['Donor ID'].nunique() == before_d, "donors lost unexpectedly"
# Out:
# nuclei : 236,002 -> 35,907
# donors : 84 -> 84
# nuclei per donor: min=63 median=376 max=1034

# %%
# Cell 7 - Region-aware neuropathology join

 
print("\n" + SEP); print("NEUROPATHOLOGY MERGE (region-aware)"); print(SEP)
 
NEUROPATH_REGION = "MTG"     # the region these measurements came from
 
NEUROPATH_COLS = [
    "percent Iba1 positive area_Grey matter",
    "number of activated Iba1 positive cells_Grey matter",
    "number of inactivated Iba1 positive cells_Grey matter",
    "number of Iba1 positive cells per area_Grey matter",
    "average Iba1 positive process length per cell_Grey matter",
    "percent AT8 positive area_Grey matter",
    "number of AT8 positive cells per area_Grey matter",
    "percent 6e10 positive area_Grey matter",
    "number of NeuN positive cells per area_Grey matter",
    "percent pTDP43 positive area_Grey matter",
    "ripa abeta42_Grey matter",
    "ripa pTau_Grey matter",
]
 
regions_present = sorted(adata.obs["Brain Region"].astype(str).unique())
print(f"regions in adata           : {regions_present}")
print(f"neuropathology measured in : {NEUROPATH_REGION}")
 
if regions_present != [NEUROPATH_REGION]:
    print(f"""
  # !! WARNING: these measurements come from {NEUROPATH_REGION} only, but the object
     spans {len(regions_present)} regions. Joining on Donor ID alone attaches {NEUROPATH_REGION}
     pathology to nuclei from every region.
 
     Either apply FIX 2 Option A first, or set NEUROPATH_VALID_ONLY_IN_MTG below
     so downstream correlations are restricted to MTG nuclei.""")
 
new_cols = [c for c in NEUROPATH_COLS if c not in adata.obs.columns]
print(f"\ncolumns to merge: {len(new_cols)}")
 
if new_cols:
    slim = neuropath[["Donor ID"] + new_cols].drop_duplicates("Donor ID")
    slim["Donor ID"] = slim["Donor ID"].astype(str)
    before = adata.obs.shape[1]
    idx = adata.obs.index
    obs = adata.obs.copy()
    obs["_donor_str"] = obs["Donor ID"].astype(str)
    obs = obs.merge(slim, left_on="_donor_str", right_on="Donor ID",
                    how="left", suffixes=("", "_np")).drop(columns=["_donor_str", "Donor ID_np"],
                                                            errors="ignore")
    obs.index = idx
    adata.obs = obs
    print(f"obs columns: {before} -> {adata.obs.shape[1]}")
 
# mark which nuclei the measurements are actually valid for
adata.obs["neuropath_valid"] = (adata.obs["Brain Region"].astype(str) == NEUROPATH_REGION)
print(f"\nnuclei where neuropathology is region-matched: "
      f"{adata.obs['neuropath_valid'].sum():,} / {adata.n_obs:,}")
 
present = [c for c in NEUROPATH_COLS if c in adata.obs.columns]
donor_np = adata.obs.drop_duplicates("Donor ID")[["Donor ID"] + present]
print(f"donors with neuropathology: {donor_np[present].notna().all(axis=1).sum()} / {len(donor_np)}")
missing = donor_np[present].isna().sum()
if missing.any():
    print("\nmissing values per column (donor level):")
    print(missing[missing > 0].to_string())
# Out:
# ...
# NEUROPATHOLOGY MERGE (region-aware)
# ...
# regions in adata           : ['MTG']
# neuropathology measured in : MTG
#
# columns to merge: 12
# obs columns: 130 -> 142
#
# nuclei where neuropathology is region-matched: 35,907 / 35,907
# donors with neuropathology: 84 / 84

# %%
# Cell 8  - Gene Set Scoring


SEP = "=" * 78

# DAM SIGNATURE - (stage, log2FC, -log10FDR, note)
DAM = {
    # ---- Stage 1: Trem2-INDEPENDENT
    "APOE":     ("DAM1", +3.429, 59.9, "canonical DAM marker; 2.92 UMI/cell baseline"),
    "TYROBP":   ("DAM1", +1.609, 49.0, "DAP12, TREM2 co-receptor"),
    "B2M":      ("DAM1", +1.375, 57.2, "MHC-I component"),
    "FTH1":     ("DAM1", +1.514, 40.0, "ferritin heavy chain"),
    "CTSB":     ("DAM1", +2.044, 65.3, "cathepsin B"),
    "CTSD":     ("DAM1", +1.452, 63.0, "cathepsin D; highest baseline at 13.8 UMI/cell"),
    "CSTB":     ("DAM1", +1.101,  4.4, "cystatin B; weakest FDR in the stage-1 set"),
    "TIMP2":    ("DAM1", +1.105, 14.2, "stage 1 per Figure 2 (an earlier revision wrongly moved this to stage 2)"),

    # ---- Stage 2: Trem2-DEPENDENT
    "CST7":     ("DAM2", +6.082, 84.9, "strongest FDR in the entire table"),
    "CLEC7A":   ("DAM2", +5.149, 40.9, "Dectin-1"),
    "LPL":      ("DAM2", +4.947, 66.1, "lipoprotein lipase"),
    "ANKH":     ("DAM2", +4.877, 49.5, "mouse Ank -> human ANKH (symbol differs)"),
    "SPP1":     ("DAM2", +4.313, 27.1, "osteopontin; 73.6% detected in these nuclei"),
    "AXL":      ("DAM2", +4.290, 45.7, "phagocytic receptor"),
    "CSF1":     ("DAM2", +5.225, 25.9, "colony stimulating factor 1"),
    "ITGAX":    ("DAM2", +7.860, 43.2, "CD11c; largest fold change (baseline 0.003 UMI/cell)"),
    "CADM1":    ("DAM2", +2.493, 31.3, "RESTORED - confirmed in Table S3"),
    "CD63":     ("DAM2", +2.326, 38.8, "RESTORED - confirmed"),
    "CD9":      ("DAM2", +2.068, 50.8, "tetraspanin"),
    "SERPINE2": ("DAM2", +1.999, 39.7, "RESTORED - confirmed"),
    "GUSB":     ("DAM2", +1.791, 25.2, "RESTORED - confirmed (also a housekeeping normaliser: see nolyso subscore)"),
    "CTSZ":     ("DAM2", +1.684, 43.4, "RESTORED - confirmed"),
    "HIF1A":    ("DAM2", +1.502, 11.5, "RESTORED - confirmed"),
    "CTSL":     ("DAM2", +1.457, 29.9, "cathepsin L"),
    "CD68":     ("DAM2", +1.339, 26.3, "RESTORED - confirmed (marks activated myeloid cells generally)"),
    "CTSA":     ("DAM2", +1.195, 19.7, "RESTORED - confirmed"),
    "TREM2":    ("DAM2", +1.227, 27.3, "MOVED from homeostatic - significantly UP in DAM. Only 22.6% detected here"),
}

# Optional DAM extension: confirmed, well-expressed in mouse
DAM_EXTENDED = {
    "GRN":   (+1.034, 24.7, "progranulin; 3.17 UMI/cell baseline; FTD/AD relevance"),
    "HEXA":  (+1.191, 22.3, "hexosaminidase A - contrast with HEXB, which does NOT change"),
    "NPC2":  (+1.673, 32.3, "lysosomal cholesterol transport"),
    "MPEG1": (+1.307, 28.3, "perforin-2; 2.02 UMI/cell baseline"),
}
INCLUDE_EXTENDED_DAM = False


# HOMEOSTATIC SIGNATURE - genes DOWN in DAM (log2FC, -log10FDR, note)
HOM = {
    # ---- Figure 2 "Downregulated in stage 1 DAM"
    "TMEM119":  (-2.456, 56.1, "largest homeostatic decrease"),
    "P2RY12":   (-2.052, 58.4, "gold-standard marker; 10.95 UMI/cell baseline"),
    "P2RY13":   (-1.587, 21.6, "co-regulated with P2RY12"),
    "TXNIP":    (-1.592, 14.1, "thioredoxin-interacting protein"),
    "CX3CR1":   (-1.360, 52.5, "fractalkine receptor; 11.15 UMI/cell baseline"),
    "SERINC3":  (-0.907, 28.2, "9.20 UMI/cell baseline"),
    "TGFBR1":   (-0.674,  7.1, "TGF-beta receptor; weakest effect in this set"),
    "GLUL":     (-1.335, 20.3, "FLAG: glutamine synthetase is heavily astrocytic - ambient RNA risk in snRNA-seq. Check detection before trusting"),

    # ---- Additional confirmed down-genes (Table S3), for list balance
    "MAF":      (-2.252, 22.7, "transcription factor"),
    "CD164":    (-2.019, 23.7, "sialomucin"),
    "ZFHX3":    (-1.976, 16.1, "zinc finger homeobox 3"),
    "SRGAP2":   (-1.737, 11.5, "SLIT-ROBO GAP"),
    "RHOB":     (-1.397, 19.3, "Rho GTPase"),
    "CMTM6":    (-1.377, 15.4, "CKLF-like MARVEL protein"),
    "ADGRG1":   (-1.375, 10.6, "mouse Gpr56 -> human ADGRG1 (symbol differs)"),
    "LPCAT2":   (-1.312, 14.4, "lysophosphatidylcholine acyltransferase"),
    "MARCKS":   (-1.293, 35.4, "6.80 UMI/cell baseline"),
    "SLCO2B1":  (-1.270, 16.3, "organic anion transporter"),
    "SELPLG":   (-1.225, 37.2, "PSGL-1; 9.07 UMI/cell baseline"),
    "SALL1":    (-1.190,  4.7, "microglial identity TF (Buttgereit 2016). Confirmed down in DAM, but low baseline (0.82) and weakest FDR here"),
    "BIN1":     (-1.170,  8.4, "major AD GWAS locus - notable that it falls with DAM transition"),
    "ITGAM":    (-1.124,  9.9, "CD11b"),
    "PMEPA1":   (-1.113, 11.0, "TGF-beta responsive"),
    "OLFML3":   (-1.078, 17.3, "in Figure 2's 'Homeostatic' panel, but Table S3 shows a real decrease - belongs here"),
    "EPB41L2":  (-1.036, 10.2, "mouse Epb4.1l2 -> human EPB41L2 (no dot)"),
    "PTGS1":    (-1.032,  8.5, "COX-1"),
}

# NEGATIVE CONTROL - genes that should NOT track pathology

CONTROL = {
    "HEXB":  (-0.036, 0.45, "NOT significant - the true invariant"),
    "C1QA":  (-0.216, 2.70, "small decrease"),
    "C1QB":  (-0.494, 8.14, "small decrease"),
    "C1QC":  (-0.467, 8.71, "small decrease"),
    "CTSS":  (+0.388, 9.19, "small INCREASE - note direction"),
    "CSF1R": (-0.469, 14.0, "small decrease; pan-microglial identity gene"),
    "CST3":  (-0.229, 5.05, "small decrease; highest baseline in table (46.4)"),
}

# BUILD LISTS
print(SEP); print("GENE LISTS FROM KEREN-SHAUL TABLE S3"); print(SEP)

dam_genes = list(DAM)
if INCLUDE_EXTENDED_DAM:
    dam_genes += list(DAM_EXTENDED)
homeostatic_genes = list(HOM)
control_genes = list(CONTROL)

# no gene may appear in two sets
for a, b, la, lb in [(dam_genes, homeostatic_genes, "DAM", "HOM"),
                     (dam_genes, control_genes, "DAM", "CONTROL"),
                     (homeostatic_genes, control_genes, "HOM", "CONTROL")]:
    ov = set(a) & set(b)
    assert not ov, f"gene(s) in both {la} and {lb}: {ov}"

var_upper = {g.upper(): g for g in adata.var_names}

def resolve(genes, label):
    found = [var_upper[g.upper()] for g in genes if g.upper() in var_upper]
    missing = [g for g in genes if g.upper() not in var_upper]
    print(f"{label:<14} requested={len(genes):<3} found={len(found):<3} "
          f"missing={missing if missing else 'none'}")
    return found

dam_genes_filtered = resolve(dam_genes, "DAM")
homeostatic_genes_filtered = resolve(homeostatic_genes, "Homeostatic")
control_genes_filtered = resolve(control_genes, "Control")

n_d, n_h = len(dam_genes_filtered), len(homeostatic_genes_filtered)
print(f"\nsizes: DAM={n_d}  Homeostatic={n_h}  ratio={n_d/max(n_h,1):.2f}")
print("  ratio near 1 -> the two scores have comparable sampling variance, so"
      "\n  relative magnitude is interpretable, not only direction."
      if n_d / max(n_h, 1) < 1.5 else
      "  ratio >1.5 -> compare DIRECTION only, never relative magnitude.")

# effect-size summary from the source
src = pd.DataFrame(
    [{"gene": g, "set": "DAM", "stage": DAM[g][0], "log2FC": DAM[g][1], "neglog10FDR": DAM[g][2]} for g in DAM] +
    ([{"gene": g, "set": "DAM_ext", "stage": "DAM", "log2FC": v[0], "neglog10FDR": v[1]} for g, v in DAM_EXTENDED.items()] if INCLUDE_EXTENDED_DAM else []) +
    [{"gene": g, "set": "HOM", "stage": "-", "log2FC": HOM[g][0], "neglog10FDR": HOM[g][1]} for g in HOM] +
    [{"gene": g, "set": "CONTROL", "stage": "-", "log2FC": CONTROL[g][0], "neglog10FDR": CONTROL[g][1]} for g in CONTROL]
)
print("\nSource effect sizes (Keren-Shaul Table S3):")
print(src.groupby("set").log2FC.agg(["count", "mean", "min", "max"]).round(3).to_string())
print("\n  CONTROL mean |log2FC| should be far smaller than DAM/HOM:")
print(f"    DAM     mean |log2FC| = {src[src.set.str.startswith('DAM')].log2FC.abs().mean():.3f}")
print(f"    HOM     mean |log2FC| = {src[src.set=='HOM'].log2FC.abs().mean():.3f}")
print(f"    CONTROL mean |log2FC| = {src[src.set=='CONTROL'].log2FC.abs().mean():.3f}")

# SUBSETS
dam1 = [g for g in dam_genes_filtered if g.upper() in DAM and DAM[g.upper()][0] == "DAM1"]
dam2 = [g for g in dam_genes_filtered if g.upper() in DAM and DAM[g.upper()][0] == "DAM2"]
LYSO = {"CTSA", "CTSB", "CTSD", "CTSL", "CTSZ", "CSTB", "CST7", "GUSB", "FTH1", "B2M"}
dam_nolyso = [g for g in dam_genes_filtered if g.upper() not in LYSO]
hom_figure = [g for g in homeostatic_genes_filtered
              if g.upper() in {"TMEM119", "P2RY12", "P2RY13", "TXNIP", "CX3CR1",
                               "SERINC3", "TGFBR1", "GLUL"}]

print(f"\nsubsets: DAM1={len(dam1)} DAM2={len(dam2)} "
      f"DAM-no-lysosomal={len(dam_nolyso)} Hom-Figure2-only={len(hom_figure)}")

# SCORING
print("\n" + SEP); print("SCORING"); print(SEP)

SCORE_KW = dict(use_raw=False, ctrl_size=50, n_bins=25, random_state=0)

for name, genes in [
    ("DAM_score",            dam_genes_filtered),
    ("Homeostatic_score",    homeostatic_genes_filtered),
    ("Control_score",        control_genes_filtered),   # <- negative control
    ("DAM1_score",           dam1),
    ("DAM2_score",           dam2),
    ("DAM_nolyso_score",     dam_nolyso),
    ("Hom_figure_score",     hom_figure),
]:
    if len(genes) < 3:
        print(f"  {name:<22} SKIPPED (only {len(genes)} gene(s))")
        continue
    sc.tl.score_genes(adata, genes, score_name=name, **SCORE_KW)
    v = adata.obs[name]
    print(f"  {name:<22} n={len(genes):<3} mean={v.mean():+.4f} sd={v.std():.4f}")

# CHECKS
print("\n" + SEP); print("CHECKS"); print(SEP)

rng = np.random.default_rng(0)
probe = rng.choice(adata.n_obs, size=min(50000, adata.n_obs), replace=False)

def rho(a, b):
    if a not in adata.obs or b not in adata.obs:
        return np.nan
    return spearmanr(adata.obs[a].values[probe], adata.obs[b].values[probe])[0]

for a, b, note in [
    ("DAM_score", "Homeostatic_score", "expect NEGATIVE - the transition is bidirectional in the source"),
    ("DAM_score", "DAM_nolyso_score",  "if <0.80, lysosomal/housekeeping genes drive the score"),
    ("Homeostatic_score", "Hom_figure_score", "if <0.90, the added genes changed what is measured"),
    ("DAM1_score", "DAM2_score",       "low => the two-stage mouse trajectory does not reproduce here"),
    ("DAM_score", "Control_score",     "should be WEAK - control genes barely move in the source"),
]:
    print(f"{a:<20} vs {b:<20} rho={rho(a,b):+.3f}   {note}")

if "total_counts" not in adata.obs.columns and "UMIs" in adata.layers:
    adata.obs["total_counts"] = np.asarray(adata.layers["UMIs"].sum(axis=1)).ravel()
if "total_counts" in adata.obs.columns:
    print("\nDepth confound:")
    for s in ["DAM_score", "Homeostatic_score", "Control_score"]:
        if s in adata.obs:
            r, p = spearmanr(adata.obs[s].values[probe],
                             adata.obs["total_counts"].values[probe])
            flag = "  <-- CONFOUND" if abs(r) > 0.2 else ""
            print(f"  {s:<20} vs total_counts rho={r:+.3f} p={p:.2e}{flag}")


# PER-GENE CONTRIBUTION - decides which genes survive in HUMAN nuclei
print("\n" + SEP); print("PER-GENE CONTRIBUTION IN THIS DATASET"); print(SEP)

def contribution(genes, label, src_lookup):
    rows = []
    for g in genes:
        j = adata.var_names.get_loc(g)
        v = adata.X[probe, j]
        v = v.toarray().ravel() if hasattr(v, "toarray") else np.asarray(v).ravel()
        det = (v > 0).mean()
        mu = v[v > 0].mean() if (v > 0).any() else 0.0
        rows.append({"gene": g,
                     "src_log2FC": src_lookup.get(g.upper(), (np.nan,))[0]
                                   if not isinstance(src_lookup.get(g.upper()), tuple)
                                   or len(src_lookup.get(g.upper(), ())) < 2 else
                                   (src_lookup[g.upper()][1] if len(src_lookup[g.upper()]) == 4
                                    else src_lookup[g.upper()][0]),
                     "detected_pct": 100 * det, "mean_nonzero": mu,
                     "contribution": det * mu})
    df = pd.DataFrame(rows).sort_values("contribution", ascending=False)
    df["share_pct"] = 100 * df.contribution / df.contribution.sum()
    print(f"\n{label} ({len(genes)} genes) - top 3 carry {df.share_pct.head(3).sum():.1f}%")
    print(df.round(3).to_string(index=False))
    weak = df[df.detected_pct < 5].gene.tolist()
    if weak:
        print(f"  !! <5% detection in human nuclei - consider dropping: {weak}")
    return df

contribution(dam_genes_filtered, "DAM", DAM)
contribution(homeostatic_genes_filtered, "HOMEOSTATIC", HOM)
contribution(control_genes_filtered, "CONTROL", CONTROL)
# Out:
# ...
# GENE LISTS FROM KEREN-SHAUL TABLE S3
# ...
# DAM            requested=27  found=27  missing=none
# Homeostatic    requested=26  found=26  missing=none
# Control        requested=7   found=7   missing=none
#
# sizes: DAM=27  Homeostatic=26  ratio=1.04
#   ratio near 1 -> the two scores have comparable sampling variance, so
#   relative magnitude is interpretable, not only direction.
#
# Source effect sizes (Keren-Shaul Table S3):
#          count   mean    min    max
# set
# CONTROL      7 -0.218 -0.494  0.388
# DAM         27  2.795  1.101  7.860
# HOM         26 -1.421 -2.456 -0.674
#
#   CONTROL mean |log2FC| should be far smaller than DAM/HOM:
#     DAM     mean |log2FC| = 2.795
#     HOM     mean |log2FC| = 1.421
#     CONTROL mean |log2FC| = 0.328
#
# subsets: DAM1=8 DAM2=19 DAM-no-lysosomal=17 Hom-Figure2-only=8
#
# ...
# SCORING
# ...
# computing score 'DAM_score'
#     finished: added
#     'DAM_score', score of gene set (adata.obs).
#     450 total control genes are used. (0:00:01)
# ...

# %%
# Cell 8B: compare supertype locations to DAM score zones
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sc.pl.umap(adata, color='Supertype', title='Supertypes', 
           show=False, ax=axes[0])
sc.pl.umap(adata, color='DAM_score', color_map='RdYlBu_r',
           title='DAM Score', show=False, ax=axes[1])
sc.pl.umap(adata, color='Homeostatic_score', color_map='RdYlBu_r',
           title='Homeostatic Score', show=False, ax=axes[2])

plt.tight_layout()
plt.savefig('../figures/umap_supertype_vs_scores.png',
            dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# %%
# Cell 8C - DAM / Homeostatic score patterns per supertype


SEP = "=" * 78
MIN_CELLS = 20          # minimum nuclei per donor x supertype to trust a mean

# 1. DONOR x SUPERTYPE MEANS
print(SEP); print("1. DONOR x SUPERTYPE AGGREGATION"); print(SEP)

ds = (adata.obs
      .groupby(["Donor ID", "Supertype"], observed=True)
      .agg(DAM=("DAM_score", "mean"),
           HOM=("Homeostatic_score", "mean"),
           CTRL=("Control_score", "mean") if "Control_score" in adata.obs else ("DAM_score", "mean"),
           n_cells=("DAM_score", "size"))
      .reset_index())

n_pairs_before = len(ds)
thin = ds[ds.n_cells < MIN_CELLS]
ds = ds[ds.n_cells >= MIN_CELLS].copy()

print(f"donor x supertype pairs : {n_pairs_before} -> {len(ds)} "
      f"(dropped {n_pairs_before - len(ds)} with <{MIN_CELLS} nuclei)")
if len(thin):
    print("\ndropped pairs by supertype:")
    print(thin.groupby("Supertype", observed=True)
          .agg(pairs_dropped=("n_cells", "size"),
               median_cells=("n_cells", "median")).to_string())

# 2. SUPERTYPE SUMMARY  (descriptive only - no tests here)
print("\n" + SEP); print("2. SUPERTYPE PROFILE (descriptive)"); print(SEP)

summary = (ds.groupby("Supertype", observed=True)
           .agg(DAM_mean=("DAM", "mean"), DAM_sd=("DAM", "std"),
                HOM_mean=("HOM", "mean"), HOM_sd=("HOM", "std"),
                n_donors=("Donor ID", "nunique"), n_cells=("n_cells", "sum"))
           .reset_index())
# difference, not ratio - ratios break when the denominator can be negative
summary["DAM_minus_HOM"] = summary.DAM_mean - summary.HOM_mean
summary = summary.sort_values("DAM_mean", ascending=False)

print(summary.round(4).to_string(index=False))
print(f"\ntotal donors in analysis: {ds['Donor ID'].nunique()}")

# 3. PAIRED TESTS - each supertype vs the same donor's other supertypes
print("\n" + SEP); print("3. PAIRED TESTS (Wilcoxon signed-rank, within donor)"); print(SEP)


def paired_vs_rest(pivot, label):
    rows = []
    for s in pivot.columns:
        others = pivot.drop(columns=s).mean(axis=1, skipna=True)
        d = (pivot[s] - others).dropna()
        if len(d) < 6:
            rows.append({"Supertype": s, "n_donors": len(d), "median_diff": np.nan,
                         "frac_positive": np.nan, "pval": np.nan})
            continue
        try:
            _, p = wilcoxon(d, alternative="two-sided")
        except ValueError:            # all differences zero
            p = 1.0
        rows.append({"Supertype": s, "n_donors": len(d),
                     "median_diff": d.median(),
                     "frac_positive": (d > 0).mean(),
                     "pval": p})
    out = pd.DataFrame(rows)
    ok = out.pval.notna()
    out.loc[ok, "padj"] = multipletests(out.loc[ok, "pval"], method="fdr_bh")[1]
    out = out.sort_values("median_diff", ascending=False)
    print(f"\n--- {label} ---")
    print(out.round(4).to_string(index=False))
    return out


piv_dam = ds.pivot(index="Donor ID", columns="Supertype", values="DAM")
piv_hom = ds.pivot(index="Donor ID", columns="Supertype", values="HOM")

res_dam = paired_vs_rest(piv_dam, "DAM score")
res_hom = paired_vs_rest(piv_hom, "Homeostatic score")

# 4. SEAAD vs CANONICAL - paired, microglial supertypes only
print("\n" + SEP); print("4. SEAAD vs CANONICAL MICROGLIA (paired)"); print(SEP)

micro = [c for c in piv_dam.columns if "Micro" in str(c)]
seaad = [c for c in micro if "SEAAD" in str(c)]
canon = [c for c in micro if "SEAAD" not in str(c)]
nonmicro = [c for c in piv_dam.columns if c not in micro]

print(f"microglial supertypes : {len(micro)}")
print(f"  SEAAD-specific      : {seaad}")
print(f"  canonical           : {canon}")
if nonmicro:
    print(f"excluded (non-microglial): {nonmicro}")

for label, piv in [("DAM", piv_dam), ("Homeostatic", piv_hom)]:
    a = piv[seaad].mean(axis=1, skipna=True)
    b = piv[canon].mean(axis=1, skipna=True)
    d = (a - b).dropna()
    _, p = wilcoxon(d, alternative="two-sided")
    print(f"\n{label}:")
    print(f"  n donors (paired) : {len(d)}     <-- donors, not donor x supertype pairs")
    print(f"  SEAAD median      : {a.loc[d.index].median():+.4f}")
    print(f"  canonical median  : {b.loc[d.index].median():+.4f}")
    print(f"  median paired diff: {d.median():+.4f}")
    print(f"  donors higher in SEAAD: {(d > 0).sum()}/{len(d)} ({100*(d>0).mean():.1f}%)")
    print(f"  Wilcoxon p        : {p:.4e}")


# 5. NON-MICROGLIAL SUPERTYPES (reported, not tested against microglia)
if nonmicro:
    print("\n" + SEP); print("5. NON-MICROGLIAL SUPERTYPES"); print(SEP)
    print(summary[summary.Supertype.isin(nonmicro)].round(4).to_string(index=False))
    micro_dam = summary[summary.Supertype.isin(micro)].DAM_mean.mean()
    print(f"\nmean DAM across microglial supertypes: {micro_dam:+.4f}")

# 6. FIGURE
colors_map = {
    "Micro-PVM_1": "#2196F3", "Micro-PVM_2": "#4CAF50",
    "Micro-PVM_2_1-SEAAD": "#F44336", "Micro-PVM_2_3-SEAAD": "#FF9800",
    "Micro-PVM_3-SEAAD": "#9C27B0", "Micro-PVM_4-SEAAD": "#E91E63",
    "Monocyte": "#795548", "Lymphocyte": "#607D8B",
}

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

for ax, col, sd_col, title in [
        (axes[0], "DAM_mean", "DAM_sd", "DAM Score by Supertype"),
        (axes[1], "HOM_mean", "HOM_sd", "Homeostatic Score by Supertype")]:
    d = summary.sort_values(col, ascending=False)
    cols = [colors_map.get(s, "#333333") for s in d.Supertype]
    ax.barh(d.Supertype, d[col], xerr=d[sd_col], color=cols, alpha=0.85, capsize=4)
    gm = d[col].mean()
    ax.axvline(gm, color="black", ls="--", lw=1.5, label=f"mean across supertypes ({gm:.2f})")
    # annotate donor n on each bar
    for y, (_, r) in enumerate(d.iterrows()):
        ax.text(0, y, f"  n={r.n_donors}", va="center", ha="left", fontsize=7)
    ax.set_xlabel(f"Mean {title.split()[0]} score (donor-aggregated)")
    ax.set_title(title + f"\n(min {MIN_CELLS} nuclei per donor)")
    ax.legend(fontsize=8)
    ax.invert_yaxis()

for _, r in summary.iterrows():
    axes[2].scatter(r.HOM_mean, r.DAM_mean,
                    color=colors_map.get(r.Supertype, "#333333"),
                    s=r.n_donors * 3, alpha=0.85,
                    edgecolors="black" if "SEAAD" in str(r.Supertype) else "none",
                    linewidth=1.5, zorder=3)
    axes[2].annotate(str(r.Supertype).replace("Micro-PVM_", ""),
                     (r.HOM_mean, r.DAM_mean), fontsize=7, ha="left",
                     xytext=(4, 2), textcoords="offset points")
axes[2].axhline(summary.DAM_mean.mean(), color="grey", ls="--", alpha=0.5)
axes[2].axvline(summary.HOM_mean.mean(), color="grey", ls="--", alpha=0.5)
axes[2].set_xlabel("Mean homeostatic score")
axes[2].set_ylabel("Mean DAM score")
axes[2].set_title("DAM vs homeostatic\n(size = donor count, outline = SEAAD subtype)")

plt.suptitle("Microglial activation profiles by supertype (donor-aggregated, paired tests)",
             fontsize=14, y=1.02)
plt.tight_layout()
plt.savefig("../figures/supertype_activation_profiles.png", dpi=300,
            bbox_inches="tight", facecolor="white")
plt.show()
plt.close()

res_dam.to_csv("../results/supertype_paired_DAM.csv", index=False)
res_hom.to_csv("../results/supertype_paired_HOM.csv", index=False)
print(f"\n{SEP}\nsaved -> ../results/supertype_paired_{{DAM,HOM}}.csv")
# Out:
# ...
# 1. DONOR x SUPERTYPE AGGREGATION
# ...
# donor x supertype pairs : 427 -> 261 (dropped 166 with <20 nuclei)
#
# dropped pairs by supertype:
#                      pairs_dropped  median_cells
# Supertype
# Micro-PVM_1                     57          10.0
# Micro-PVM_2                      1          10.0
# Micro-PVM_2_1-SEAAD             40           3.0
# Micro-PVM_2_3-SEAAD              5          18.0
# Micro-PVM_3-SEAAD               17          15.0
# Micro-PVM_4-SEAAD               46           2.0
#
# ...
# 2. SUPERTYPE PROFILE (descriptive)
# ...
#           Supertype  DAM_mean  DAM_sd  HOM_mean  HOM_sd  n_donors  n_cells  DAM_minus_HOM
#   Micro-PVM_4-SEAAD    1.1385  0.0229    0.5697  0.1018         2      256         0.5688
#   Micro-PVM_3-SEAAD    0.8159  0.1629    0.9796  0.1349        67     4216        -0.1637
#         Micro-PVM_2    0.6914  0.1739    1.1556  0.1483        83    21080        -0.4642
# ...

# %%
# Cell 8C Diagnostic - Run paired test on control score: should be flat across supertypes
piv_ctrl = ds.pivot(index="Donor ID", columns="Supertype", values="CTRL")
res_ctrl = paired_vs_rest(piv_ctrl, "Control score")

# Update, was not flat across supertypes (Micro-PVM_2_3 & Micro-PVM_2). Test differences instead of raw scores
ds["DAM_adj"] = ds["DAM"] - ds["CTRL"]
ds["HOM_adj"] = ds["HOM"] - ds["CTRL"]

piv_dam_adj = ds.pivot(index="Donor ID", columns="Supertype", values="DAM_adj")
piv_hom_adj = ds.pivot(index="Donor ID", columns="Supertype", values="HOM_adj")

res_dam_adj = paired_vs_rest(piv_dam_adj, "DAM (control-adjusted)")
res_hom_adj = paired_vs_rest(piv_hom_adj, "Homeostatic (control-adjusted)")
# Out:
# --- Control score ---
#           Supertype  n_donors  median_diff  frac_positive   pval   padj
#         Micro-PVM_2        80       0.2812         0.9375 0.0000 0.0000
#         Micro-PVM_1        26       0.0781         0.5769 0.4082 0.4082
#   Micro-PVM_3-SEAAD        66      -0.0692         0.4091 0.0518 0.0690
# Micro-PVM_2_3-SEAAD        79      -0.2271         0.1139 0.0000 0.0000
# Micro-PVM_2_1-SEAAD         4          NaN            NaN    NaN    NaN
#   Micro-PVM_4-SEAAD         2          NaN            NaN    NaN    NaN
#
# --- DAM (control-adjusted) ---
#           Supertype  n_donors  median_diff  frac_positive   pval   padj
#   Micro-PVM_3-SEAAD        66       0.2413         0.9091 0.0000 0.0000
# Micro-PVM_2_3-SEAAD        79       0.0671         0.7215 0.0017 0.0023
#         Micro-PVM_1        26      -0.1687         0.3462 0.0312 0.0312
#         Micro-PVM_2        80      -0.2423         0.0625 0.0000 0.0000
# ...

# %%
# Cell 9 - Subtype composition vs Braak stage


SEP = "=" * 78
MIN_CELLS_PER_DONOR = 50     # drop donors with too few nuclei to give a stable %
MIN_DONORS = 5               # Braak stages below this are flagged, not trusted

BRAAK_ORDER = {"Braak 0": 0, "Braak I": 1, "Braak II": 2, "Braak III": 3,
               "Braak IV": 4, "Braak V": 5, "Braak VI": 6}

# 1. MICROGLIAL DENOMINATOR
print(SEP); print("1. DEFINING THE DENOMINATOR"); print(SEP)

all_supertypes = [str(s) for s in adata.obs["Supertype"].unique()]
MICRO = sorted([s for s in all_supertypes if "Micro" in s])
NONMICRO = sorted([s for s in all_supertypes if s not in MICRO])

print(f"microglial supertypes (denominator): {MICRO}")
print(f"excluded from denominator          : {NONMICRO if NONMICRO else 'none (already filtered)'}")

mask = adata.obs["Supertype"].astype(str).isin(MICRO).values
sub = adata.obs.loc[mask]
print(f"\nnuclei in denominator: {mask.sum():,} of {adata.n_obs:,}")

# 2. COMPOSITION PER DONOR
print("\n" + SEP); print("2. COMPOSITION PER DONOR"); print(SEP)

counts = (sub.groupby(["Donor ID", "Supertype"], observed=True)
          .size().unstack(fill_value=0))
counts = counts[[c for c in counts.columns if str(c) in MICRO]]

per_donor_total = counts.sum(axis=1)
thin_donors = per_donor_total[per_donor_total < MIN_CELLS_PER_DONOR]
if len(thin_donors):
    print(f"dropping {len(thin_donors)} donor(s) with <{MIN_CELLS_PER_DONOR} microglial nuclei:")
    print(thin_donors.to_string())
counts = counts.loc[per_donor_total >= MIN_CELLS_PER_DONOR]

pct = counts.div(counts.sum(axis=1), axis=0) * 100
print(f"\ndonors retained: {len(pct)}")
print(f"microglial nuclei per donor: min={counts.sum(1).min():,} "
      f"median={counts.sum(1).median():,.0f} max={counts.sum(1).max():,}")

# attach donor metadata
donor_meta = (adata.obs[["Donor ID", "Braak", "Cognitive Status"]]
              .drop_duplicates("Donor ID").set_index("Donor ID"))
donor_meta.index = donor_meta.index.astype(str)
pct.index = pct.index.astype(str)
pct = pct.join(donor_meta, how="left")
pct["Braak_num"] = pct["Braak"].astype(str).map(BRAAK_ORDER)

stage_n = pct.groupby("Braak", observed=True).size().sort_index()
print("\ndonors per Braak stage:")
for stage, n in stage_n.items():
    flag = f"   <-- only {n} donor(s); not trustworthy" if n < MIN_DONORS else ""
    print(f"  {stage:<12} n={n}{flag}")

small_stages = stage_n[stage_n < MIN_DONORS].index.tolist()
if small_stages:
    print(f"\nstages excluded from the trend test: {small_stages}")

# 3. STATISTICS
print("\n" + SEP); print("3. COMPOSITION vs BRAAK"); print(SEP)

test_df = pct[~pct["Braak"].astype(str).isin(small_stages)].copy()
print(f"donors in tests: {len(test_df)} across {test_df['Braak'].nunique()} stages\n")

rows = []
for s in MICRO:
    if s not in test_df.columns:
        continue
    d = test_df[[s, "Braak_num", "Braak"]].dropna()
    rho, p_sp = spearmanr(d[s], d["Braak_num"])
    groups = [g[s].values for _, g in d.groupby("Braak", observed=True) if len(g) >= 3]
    try:
        _, p_kw = kruskal(*groups) if len(groups) >= 2 else (np.nan, np.nan)
    except ValueError:
        p_kw = np.nan
    rows.append({"Supertype": s, "mean_pct": d[s].mean(),
                 "spearman_rho": rho, "p_spearman": p_sp, "p_kruskal": p_kw})

res = pd.DataFrame(rows)
for col, out in [("p_spearman", "padj_spearman"), ("p_kruskal", "padj_kruskal")]:
    ok = res[col].notna()
    res.loc[ok, out] = multipletests(res.loc[ok, col], method="fdr_bh")[1]
res = res.sort_values("spearman_rho", ascending=False)

print(res.round(4).to_string(index=False))
n_sig = (res.padj_spearman < 0.05).sum()
print(f"\nsupertypes with FDR-significant Braak trend: {n_sig} / {len(res)}")

# same against cognitive status
print("\n--- composition vs cognitive status ---")
cs_rows = []
for s in MICRO:
    if s not in pct.columns:
        continue
    d = pct[[s, "Cognitive Status"]].dropna()
    lv = d["Cognitive Status"].astype(str).unique()
    if len(lv) != 2:
        continue
    a = d.loc[d["Cognitive Status"].astype(str) == lv[0], s]
    b = d.loc[d["Cognitive Status"].astype(str) == lv[1], s]
    _, p = mannwhitneyu(a, b, alternative="two-sided")
    cs_rows.append({"Supertype": s, f"{lv[0]}_median": a.median(),
                    f"{lv[1]}_median": b.median(), "n_a": len(a), "n_b": len(b), "pval": p})
cs = pd.DataFrame(cs_rows)
if len(cs):
    cs["padj"] = multipletests(cs.pval, method="fdr_bh")[1]
    print(cs.round(4).to_string(index=False))

# 4. FIGURE - n annotated on every box

plot_types = ["Micro-PVM_2", "Micro-PVM_2_3-SEAAD", "Micro-PVM_3-SEAAD"]
melt = (pct.reset_index()
        .melt(id_vars=["Donor ID", "Braak", "Cognitive Status", "Braak_num"],
              value_vars=plot_types, var_name="Supertype", value_name="Proportion")
        .dropna(subset=["Braak_num"]))

order = [b for b in BRAAK_ORDER if b in melt["Braak"].astype(str).unique()]
palette = {"Micro-PVM_2": "#4CAF50", "Micro-PVM_2_3-SEAAD": "#FF9800",
           "Micro-PVM_3-SEAAD": "#9C27B0"}

fig, ax = plt.subplots(figsize=(13, 5.5))
sns.boxplot(data=melt, x="Braak", y="Proportion", hue="Supertype",
            order=order, palette=palette, ax=ax)

ymax = melt["Proportion"].max()
for i, stage in enumerate(order):
    n = stage_n.get(stage, 0)
    warn = "*" if n < MIN_DONORS else ""
    ax.text(i, ymax * 1.04, f"n={n}{warn}", ha="center", fontsize=9,
            color="crimson" if n < MIN_DONORS else "black")

ax.set_title("Microglial subtype abundance by Braak stage\n"
             f"(% of microglial nuclei per donor; * = fewer than {MIN_DONORS} donors)")
ax.set_ylabel("% of microglial nuclei per donor")
ax.set_xlabel("Braak stage")
ax.set_ylim(top=ymax * 1.12)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)
plt.tight_layout()
plt.savefig("../figures/composition_braak.png", dpi=300,
            bbox_inches="tight", facecolor="white")
plt.show()
plt.close()

res.to_csv("../results/composition_vs_braak.csv", index=False)
print(f"\n{SEP}\nsaved -> ../results/composition_vs_braak.csv")
# Out:
# ...
# 1. DEFINING THE DENOMINATOR
# ...
# microglial supertypes (denominator): ['Micro-PVM_1', 'Micro-PVM_2', 'Micro-PVM_2_1-SEAAD', 'Micro-PVM_2_3-SEAAD', 'Micro-PVM_3-SEAAD', 'Micro-PVM_4-SEAAD']
# excluded from denominator          : none (already filtered)
#
# nuclei in denominator: 35,907 of 35,907
#
# ...
# 2. COMPOSITION PER DONOR
# ...
#
# donors retained: 84
# microglial nuclei per donor: min=63 median=376 max=1,034
#
# donors per Braak stage:
#   Braak 0      n=2   <-- only 2 donor(s); not trustworthy
#   Braak II     n=4   <-- only 4 donor(s); not trustworthy
#   Braak III    n=6
#   Braak IV     n=23
#   Braak V      n=34
#   Braak VI     n=15
#
# stages excluded from the trend test: ['Braak 0', 'Braak II']
#
# ...
# 3. COMPOSITION vs BRAAK
# ...
# donors in tests: 78 across 4 stages
#
#           Supertype  mean_pct  spearman_rho  p_spearman  p_kruskal  padj_spearman  padj_kruskal
#   Micro-PVM_3-SEAAD   13.9274        0.3951      0.0003     0.0003         0.0021        0.0019
# ...

# %%
# Cell 10 - Correlation Analysis: DAM score vs Neuropathological Variables (Donor Level)
# Ordinal encoding
braak_order = {'Braak 0': 0, 'Braak II': 2, 'Braak III': 3, 'Braak IV': 4, 'Braak V': 5, 'Braak VI': 6}
cerad_order = {'Absent': 0, 'Sparse': 1, 'Moderate': 2, 'Frequent': 3}
thal_order  = {'Thal 0': 0, 'Thal 1': 1, 'Thal 2': 2, 'Thal 3': 3, 'Thal 4': 4, 'Thal 5': 5}
adnc_order  = {'Not AD': 0, 'Low': 1, 'Intermediate': 2, 'High': 3}
cog_order   = {'No dementia': 0, 'Dementia': 1}

adata.obs['Braak_num']     = adata.obs['Braak'].map(braak_order)
adata.obs['CERAD_num']     = adata.obs['CERAD score'].map(cerad_order)
adata.obs['Thal_num']      = adata.obs['Thal'].map(thal_order)
adata.obs['ADNC_num']      = adata.obs['Overall AD neuropathological Change'].map(adnc_order)
adata.obs['CogStatus_num'] = adata.obs['Cognitive Status'].map(cog_order)

# Aggregate to donor level
donor_df = adata.obs.groupby('Donor ID').agg(
    DAM_score         = ('DAM_score', 'mean'),
    Homeostatic_score = ('Homeostatic_score', 'mean'),
    Braak_num         = ('Braak_num', 'first'),
    CERAD_num         = ('CERAD_num', 'first'),
    Thal_num          = ('Thal_num', 'first'),
    ADNC_num          = ('ADNC_num', 'first'),
    CogStatus_num     = ('CogStatus_num', 'first'),
    Age_at_Death      = ('Age at Death', 'first'),
).reset_index()

print(f"Number of donors: {len(donor_df)}")
print(donor_df.head())

# Spearman correlations
correlations = {}
for col, label in [('Braak_num',     'Braak Stage'),
                   ('CERAD_num',     'CERAD Score'),
                   ('Thal_num',      'Thal Phase'),
                   ('ADNC_num',      'Overall AD Neuropathological Change'),
                   ('CogStatus_num', 'Cognitive Status'),
                   ('Age_at_Death',  'Age at Death')]:
    df_tmp = donor_df[['DAM_score', col]].dropna()
    rho, pval = stats.spearmanr(df_tmp['DAM_score'], df_tmp[col])
    correlations[label] = {'rho': round(rho, 4), 'p': round(pval, 4)}

corr_df = pd.DataFrame(correlations).T
corr_df['significant'] = corr_df['p'] < 0.05
print("\nCorrelation results:")
print(corr_df)

corr_df["padj"] = multipletests(corr_df["p"], method="fdr_bh")[1]
corr_df["significant"] = corr_df["padj"] < 0.05

# Plot: correlation bar chart
fig, ax = plt.subplots(figsize=(8, 5))
colors = ['steelblue' if s else 'lightgrey' for s in corr_df['significant']]
ax.barh(corr_df.index, corr_df['rho'], color=colors)
ax.axvline(0, color='black', linewidth=0.8)
ax.set_xlabel("Spearman's rho")
ax.set_title("DAM Score Correlation with Neuropathological Variables\n(Donor Level)")
plt.tight_layout()
plt.savefig('../figures/DAM_correlations_donor_level.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# Plot: DAM score by Braak stage (boxplot)
donor_df['Braak'] = adata.obs.groupby('Donor ID')['Braak'].first().values
fig, ax = plt.subplots(figsize=(8, 5))
braak_order_list = ['Braak 0', 'Braak II', 'Braak III', 'Braak IV', 'Braak V', 'Braak VI']
sns.boxplot(data=donor_df, x='Braak', y='DAM_score', order=braak_order_list,
            palette='Blues', ax=ax)
ax.set_title('DAM Score by Braak Stage (Donor Level)')
ax.set_xlabel('Braak Stage')
ax.set_ylabel('Mean DAM Score per Donor')
plt.tight_layout()
plt.savefig('../figures/DAM_by_Braak_donor_level.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
plt.close()

# using neuropathology
print("\n" + SEP); print("DAM SCORE vs QUANTITATIVE NEUROPATHOLOGY"); print(SEP)
 
RESTRICT_TO_VALID_REGION = True     # correlate using MTG nuclei only
 
obs = adata.obs
if RESTRICT_TO_VALID_REGION and "neuropath_valid" in obs.columns:
    obs = obs[obs["neuropath_valid"]]
    print(f"restricted to {NEUROPATH_REGION}: {len(obs):,} nuclei, "
          f"{obs['Donor ID'].nunique()} donors")
 
SCORES = [s for s in ["DAM_score", "Homeostatic_score", "Control_score"]
          if s in obs.columns]
 
agg = {s: (s, "mean") for s in SCORES}
agg["n_cells"] = ("Donor ID", "size")
for c in [c for c in NEUROPATH_COLS if c in obs.columns]:
    agg[c] = (c, "first")
donor_df = obs.groupby("Donor ID", observed=True).agg(**agg).reset_index()
donor_df = donor_df[donor_df.n_cells >= 50]
print(f"donors in analysis: {len(donor_df)}\n")
 
LABELS = {
    "percent Iba1 positive area_Grey matter": "Iba1 area % (microglial burden)",
    "number of activated Iba1 positive cells_Grey matter": "Activated Iba1+ cells",
    "number of inactivated Iba1 positive cells_Grey matter": "Inactivated Iba1+ cells",
    "number of Iba1 positive cells per area_Grey matter": "Iba1+ cell density",
    "average Iba1 positive process length per cell_Grey matter": "Iba1 process length",
    "percent AT8 positive area_Grey matter": "AT8 area % (tau)",
    "number of AT8 positive cells per area_Grey matter": "AT8+ cell density (tau)",
    "percent 6e10 positive area_Grey matter": "6e10 area % (amyloid)",
    "number of NeuN positive cells per area_Grey matter": "NeuN+ density (NEGATIVE CONTROL)",
    "percent pTDP43 positive area_Grey matter": "pTDP43 area %",
    "ripa abeta42_Grey matter": "RIPA Abeta42",
    "ripa pTau_Grey matter": "RIPA pTau",
}
 
rows = []
for score in SCORES:
    for col, label in LABELS.items():
        if col not in donor_df.columns:
            continue
        d = donor_df[[score, col]].apply(pd.to_numeric, errors="coerce").dropna()
        if len(d) < 10:
            continue
        rho, p = spearmanr(d[score], d[col])
        rows.append({"score": score, "measure": label, "rho": rho,
                     "pval": p, "n": len(d)})
 
res_np = pd.DataFrame(rows)
# correct within each score separately - one test family per score
for s in res_np.score.unique():
    m = res_np.score == s
    res_np.loc[m, "padj"] = multipletests(res_np.loc[m, "pval"], method="fdr_bh")[1]
res_np["significant"] = res_np.padj < 0.05
 
for s in SCORES:
    print(f"--- {s} ---")
    print(res_np[res_np.score == s]
          .sort_values("rho", key=abs, ascending=False)
          [["measure", "rho", "pval", "padj", "n", "significant"]]
          .round(4).to_string(index=False))
    print()
 
print(f"FDR-significant correlations: {res_np.significant.sum()} of {len(res_np)}")
 
res_np.to_csv("../results/dam_vs_neuropathology.csv", index=False)
print(f"\nsaved -> ../results/dam_vs_neuropathology.csv")
# Out:
# Number of donors: 84
#      Donor ID  DAM_score  Homeostatic_score Braak_num CERAD_num Thal_num  \
# 0  H19.33.004   0.550357           1.062046         4         0        0
# 1  H20.33.001   0.711333           1.176871         4         1        2
# 2  H20.33.002   0.562177           1.119502         4         0        0
# 3  H20.33.004   1.041631           0.930691         5         3        5
# 4  H20.33.005   0.476707           1.113966         4         2        3
#
#   ADNC_num CogStatus_num  Age_at_Death
# 0        0             0          80.0
# 1        1             0          82.0
# 2        0             0          97.0
# 3        3             1          86.0
# 4        2             0          99.0
#
# Correlation results:
#                                         rho       p  significant
# Braak Stage                          0.2737  0.0118         True
# CERAD Score                          0.2635  0.0155         True
# ...

# %%
# Cell 10 Diagnostic - Negative-control and depth check (self-contained)

def num(s):
    """Categorical / object / numeric -> float, index preserved."""
    return pd.to_numeric(s.astype(str), errors="coerce")

if "total_counts" not in adata.obs.columns:
    adata.obs["total_counts"] = np.asarray(adata.layers["UMIs"].sum(axis=1)).ravel()

SCORES = [s for s in ["DAM_score", "Homeostatic_score", "Control_score"]
          if s in adata.obs.columns]
print("scores found:", SCORES)

agg = {s: (s, "mean") for s in SCORES}
agg["depth"]   = ("total_counts", "median")
agg["n_cells"] = ("total_counts", "size")
for c in ["Braak_num", "CERAD_num", "Thal_num", "CogStatus_num"]:
    if c in adata.obs.columns:
        agg[c] = (c, "first")

dd = adata.obs.groupby("Donor ID", observed=True).agg(**agg)
dd = dd[dd.n_cells >= 50]
print(f"donors: {len(dd)}\n")

PATH = [("Braak_num", "Braak"), ("CERAD_num", "CERAD"),
        ("Thal_num", "Thal"), ("CogStatus_num", "Cognitive")]
PATH = [(c, l) for c, l in PATH if c in dd.columns]

for score in SCORES:
    print(f"--- {score} ---")
    for col, lab in PATH:
        d = pd.concat([num(dd[score]), num(dd[col])], axis=1).dropna()
        rho, p = spearmanr(d.iloc[:, 0], d.iloc[:, 1])
        print(f"  {lab:<10} rho={rho:+.3f}  p={p:.4f}")
    print()

print("--- sequencing depth ---")
for col, lab in PATH:
    d = pd.concat([num(dd["depth"]), num(dd[col])], axis=1).dropna()
    rho, p = spearmanr(d.iloc[:, 0], d.iloc[:, 1])
    flag = "  <-- ALTERNATIVE EXPLANATION" if p < 0.05 else ""
    print(f"  depth vs {lab:<10} rho={rho:+.3f}  p={p:.4f}{flag}")

for score in SCORES:
    d = pd.concat([num(dd[score]), num(dd["depth"])], axis=1).dropna()
    rho, p = spearmanr(d.iloc[:, 0], d.iloc[:, 1])
    print(f"  {score:<20} vs depth  rho={rho:+.3f}  p={p:.4f}")

# does complement drive the Control_score correlation?
print("--- Control_score vs complement genes ---")
for g in ["C1QA","C1QB","C1QC","CSF1R","CST3","CTSS","HEXB"]:
    j = adata.var_names.get_loc(g)
    v = adata.X[:, j]
    v = v.toarray().ravel() if hasattr(v,"toarray") else np.asarray(v).ravel()
    dv = pd.Series(v, index=adata.obs["Donor ID"].values).groupby(level=0).mean()
    d = pd.concat([dv, num(dd["CERAD_num"])], axis=1).dropna()
    rho, p = spearmanr(d.iloc[:,0], d.iloc[:,1])
    print(f"  {g:<7} vs CERAD  rho={rho:+.3f}  p={p:.4f}")
# Out:
# scores found: ['DAM_score', 'Homeostatic_score', 'Control_score']
# donors: 84
#
# --- DAM_score ---
#   Braak      rho=+0.274  p=0.0118
#   CERAD      rho=+0.263  p=0.0155
#   Thal       rho=+0.258  p=0.0176
#   Cognitive  rho=+0.286  p=0.0084
#
# --- Homeostatic_score ---
#   Braak      rho=-0.188  p=0.0864
#   CERAD      rho=-0.201  p=0.0663
#   Thal       rho=-0.124  p=0.2625
#   Cognitive  rho=-0.175  p=0.1118
#
# --- Control_score ---
#   Braak      rho=+0.206  p=0.0601
#   CERAD      rho=+0.264  p=0.0152
#   Thal       rho=+0.272  p=0.0123
#   Cognitive  rho=+0.107  p=0.3325
#
# --- sequencing depth ---
#   depth vs Braak      rho=+0.137  p=0.2130
#   depth vs CERAD      rho=+0.188  p=0.0863
#   depth vs Thal       rho=+0.055  p=0.6206
#   depth vs Cognitive  rho=+0.311  p=0.0039  <-- ALTERNATIVE EXPLANATION
#   DAM_score            vs depth  rho=-0.004  p=0.9739
#   Homeostatic_score    vs depth  rho=+0.047  p=0.6721
#   Control_score        vs depth  rho=-0.137  p=0.2145
# ...

# %%
# Cell 10B - Composition vs Quantitative Neuropathology
 
SEP = "=" * 78
MIN_CELLS = 50
DAM_HIGH = "Micro-PVM_3-SEAAD"      # control-adjusted DAM +0.241 (cell 8C)
REFERENCE = "Micro-PVM_2"           # largest population; control-adjusted DAM -0.242
 
 
def num(s):
    """Categorical / object / numeric -> float, index preserved."""
    return pd.to_numeric(pd.Series(s).astype(str), errors="coerce")
 
 
# 1. DONOR TABLE: composition + scores + histology
print(SEP); print("1. BUILDING DONOR TABLE"); print(SEP)
 
comp = (adata.obs.groupby(["Donor ID", "Supertype"], observed=True)
        .size().unstack(fill_value=0))
comp = comp[[c for c in comp.columns if "Micro" in str(c)]]   # microglial denominator
comp = comp[comp.sum(axis=1) >= MIN_CELLS]
pct_c = comp.div(comp.sum(axis=1), axis=0) * 100
pct_c.index = pct_c.index.astype(str)
 
print(f"donors: {len(pct_c)}")
print(f"{DAM_HIGH:<20} mean {pct_c[DAM_HIGH].mean():5.2f}% of microglia")
print(f"{REFERENCE:<20} mean {pct_c[REFERENCE].mean():5.2f}%")
 
SCORES = [s for s in ["DAM_score", "Control_score"] if s in adata.obs.columns]
agg = {s: (s, "mean") for s in SCORES}
HISTOLOGY = {
    "percent Iba1 positive area_Grey matter":              "Iba1 area % (microglial burden)",
    "number of Iba1 positive cells per area_Grey matter":  "Iba1+ cell density",
    "number of activated Iba1 positive cells_Grey matter": "Activated Iba1+ cells (morphology)",
    "average Iba1 positive process length per cell_Grey matter": "Iba1 process length (morphology)",
    "percent AT8 positive area_Grey matter":               "AT8 area % (tau)",
    "percent 6e10 positive area_Grey matter":              "6e10 area % (amyloid)",
    "number of NeuN positive cells per area_Grey matter":  "NeuN+ density (NEG CONTROL)",
}
HISTOLOGY = {k: v for k, v in HISTOLOGY.items() if k in adata.obs.columns}
for c in HISTOLOGY:
    agg[c] = (c, "first")
 
dd = adata.obs.groupby("Donor ID", observed=True).agg(**agg)
dd.index = dd.index.astype(str)
dd = dd.loc[dd.index.intersection(pct_c.index)]
print(f"histology measures available: {len(HISTOLOGY)}")
 
# 2. COMPOSITIONAL MEASURES
p_safe = (pct_c / 100).replace(0, 1e-6)
dd["pct_DAMhigh"] = pct_c.loc[dd.index, DAM_HIGH].values
dd["logratio"] = np.log2(p_safe.loc[dd.index, DAM_HIGH].values /
                         p_safe.loc[dd.index, REFERENCE].values)
 
MEASURES = {
    "pct_DAMhigh":   f"% {DAM_HIGH}",
    "logratio":      f"log2({DAM_HIGH} / {REFERENCE})",
    "DAM_score":     "mean DAM score",
    "Control_score": "Control score (NEG CONTROL)",
}
MEASURES = {k: v for k, v in MEASURES.items() if k in dd.columns}
 
# 3. CORRELATIONS
print("\n" + SEP); print("3. CORRELATIONS WITH HISTOLOGY"); print(SEP)
 
rows = []
for m, mlabel in MEASURES.items():
    for col, clabel in HISTOLOGY.items():
        d = pd.concat([num(dd[m]).rename("x"), num(dd[col]).rename("y")],
                      axis=1).dropna()
        if len(d) < 10:
            continue
        rho, pv = spearmanr(d.x, d.y)
        rows.append({"measure": mlabel, "stain": clabel,
                     "rho": rho, "pval": pv, "n": len(d)})
 
res = pd.DataFrame(rows)
for m in res.measure.unique():                     # one test family per measure
    sel = res.measure == m
    res.loc[sel, "padj"] = multipletests(res.loc[sel, "pval"], method="fdr_bh")[1]
 
for m in MEASURES.values():
    sub = res[res.measure == m]
    if not len(sub):
        continue
    print(f"\n--- {m} ---")
    print(sub.sort_values("rho", key=abs, ascending=False)
          [["stain", "rho", "pval", "padj", "n"]].round(4).to_string(index=False))
 

# 4. SPECIFICITY TABLE 
print("\n" + SEP); print("4. SPECIFICITY: each measure vs the negative control"); print(SEP)
 
pivot = res.pivot(index="stain", columns="measure", values="rho")
ctrl_col = next((c for c in pivot.columns if "NEG CONTROL" in c), None)
if ctrl_col:
    pivot["|gap| vs control"] = (pivot.drop(columns=ctrl_col).abs().max(axis=1)
                                 - pivot[ctrl_col].abs())
print(pivot.round(3).to_string())
 
res.to_csv("../results/composition_vs_histology.csv", index=False)
print(f"saved -> ../results/composition_vs_histology.csv")
 
# 5. FIGURE 
STAINS = [
    ("percent AT8 positive area_Grey matter",  "AT8 positive area (%) — tau"),
    ("percent Iba1 positive area_Grey matter", "Iba1 positive area (%) — microglial burden"),
]
PANELS = [
    ("pct_DAMhigh",   f"% {DAM_HIGH}"),
    ("DAM_score",     "Mean DAM score"),
    ("Control_score", "Control score (NEG CONTROL)"),
]
STAINS = [(c, l) for c, l in STAINS if c in dd.columns]
PANELS = [(m, l) for m, l in PANELS if m in dd.columns]

cog = adata.obs.drop_duplicates("Donor ID").set_index("Donor ID")["Cognitive Status"]
cog.index = cog.index.astype(str)

fig, axes = plt.subplots(len(STAINS), len(PANELS),
                         figsize=(5.5 * len(PANELS), 4.8 * len(STAINS)))
axes = np.atleast_2d(axes)

for r, (stain, xlabel) in enumerate(STAINS):
    for c, (m, ylabel) in enumerate(PANELS):
        ax = axes[r, c]
        d = pd.concat([num(dd[m]).rename("y"),
                       num(dd[stain]).rename("x"),
                       cog.reindex(dd.index).astype(str).rename("cog")],
                      axis=1).dropna()
        for lvl, col in [("No dementia", "steelblue"), ("Dementia", "tomato")]:
            s = d[d.cog == lvl]
            ax.scatter(s.x, s.y, color=col, alpha=0.75, s=35, label=lvl)

        rho, pv = spearmanr(d.x, d.y)
        # trend line only when the relationship is actually there
        if pv < 0.05:
            z = np.polyfit(d.x, d.y, 1)
            xs = np.linspace(d.x.min(), d.x.max(), 50)
            ax.plot(xs, np.polyval(z, xs), color="black", ls="--", lw=1.2, alpha=0.7)

        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
        ax.set_title(f"rho={rho:+.3f}, p={pv:.4f}, n={len(d)}",
                     fontweight="bold" if pv < 0.05 else "normal")
        if r == 0 and c == 0:
            ax.legend(fontsize=8)

plt.suptitle("Tau burden tracks subtype composition; microglial burden tracks mean score",
             fontsize=13, y=1.00)
plt.tight_layout()
plt.savefig("../figures/composition_vs_histology.png", dpi=300,
            bbox_inches="tight", facecolor="white")
plt.show(); plt.close()
# Out:
# ...
# 1. BUILDING DONOR TABLE
# ...
# donors: 84
# Micro-PVM_3-SEAAD    mean 13.43% of microglia
# Micro-PVM_2          mean 56.81%
# histology measures available: 7
#
# ...
# 3. CORRELATIONS WITH HISTOLOGY
# ...
#
# --- % Micro-PVM_3-SEAAD ---
#                              stain     rho   pval   padj  n
#                   AT8 area % (tau)  0.5097 0.0000 0.0000 84
#              6e10 area % (amyloid)  0.3439 0.0014 0.0048 84
# Activated Iba1+ cells (morphology) -0.2228 0.0416 0.0971 84
#   Iba1 process length (morphology)  0.1761 0.1091 0.1910 84
#        NeuN+ density (NEG CONTROL) -0.1124 0.3087 0.4289 84
#                 Iba1+ cell density -0.0995 0.3676 0.4289 84
#    Iba1 area % (microglial burden)  0.0723 0.5133 0.5133 84
#
# --- log2(Micro-PVM_3-SEAAD / Micro-PVM_2) ---
#                              stain     rho   pval   padj  n
#                   AT8 area % (tau)  0.4640 0.0000 0.0001 84
#              6e10 area % (amyloid)  0.2947 0.0065 0.0227 84
# ...

# %%
# Cell 11 - APOE4 and microglial state


SEP = "=" * 78
MIN_CELLS = 50
DAM_HIGH = "Micro-PVM_3-SEAAD"
SCORE_KW = dict(use_raw=False, ctrl_size=50, n_bins=25, random_state=0)


def num(s):
    """Turn a categorical or text column into numbers."""
    return pd.to_numeric(pd.Series(s).astype(str), errors="coerce")


def rank_biserial(a, b):
    """Effect size for Mann-Whitney. Ranges -1 to +1.
    Positive = group a tends to score higher. 0.25 is roughly a 63% chance
    that a random member of a beats a random member of b."""
    u, p = mannwhitneyu(a, b, alternative="two-sided")
    return 2 * u / (len(a) * len(b)) - 1, p


# 1. APOE-FREE DAM SCORE 
print(SEP); print("1. APOE-FREE SCORE"); print(SEP)

dam_noapoe = [g for g in dam_genes_filtered if g.upper() != "APOE"]
print(f"DAM genes: {len(dam_genes_filtered)} -> {len(dam_noapoe)} (APOE removed)")
sc.tl.score_genes(adata, dam_noapoe, score_name="DAM_noAPOE", **SCORE_KW)

r = spearmanr(adata.obs["DAM_score"], adata.obs["DAM_noAPOE"])[0]
print(f"DAM_score vs DAM_noAPOE: rho={r:+.3f}  (high = APOE was not driving it)")

# 2. DONOR TABLE
print("\n" + SEP); print("2. DONOR TABLE"); print(SEP)

SCORES = [s for s in ["DAM_score", "DAM_noAPOE", "Homeostatic_score", "Control_score"]
          if s in adata.obs.columns]

agg = {s: (s, "mean") for s in SCORES}
agg["n_cells"] = ("Donor ID", "size")
agg["APOE_Genotype"] = ("APOE Genotype", "first")

dd = adata.obs.groupby("Donor ID", observed=True).agg(**agg)
dd = dd[dd.n_cells >= MIN_CELLS]
dd.index = dd.index.astype(str)

# composition: % of the DAM-high subtype per donor
comp = (adata.obs.groupby(["Donor ID", "Supertype"], observed=True)
        .size().unstack(fill_value=0))
comp = comp[[c for c in comp.columns if "Micro" in str(c)]]
pct_c = comp.div(comp.sum(axis=1), axis=0) * 100
pct_c.index = pct_c.index.astype(str)
dd["pct_DAMhigh"] = pct_c.loc[dd.index, DAM_HIGH].values

# APOE4 status and E4 copy number
dd["APOE_Genotype"] = dd["APOE_Genotype"].astype(str)
dd["E4_copies"] = dd["APOE_Genotype"].str.count("4")
dd["APOE4_status"] = np.where(dd.E4_copies > 0, "Carrier", "Non-carrier")

print(f"donors: {len(dd)}")
print(f"carriers: {(dd.APOE4_status == 'Carrier').sum()}   "
      f"non-carriers: {(dd.APOE4_status == 'Non-carrier').sum()}")
print("\nE4 copies per donor:")
print(dd.E4_copies.value_counts().sort_index().to_string())
print("\ngenotype counts:")
print(dd.APOE_Genotype.value_counts().to_string())

# 3. CARRIER vs NON-CARRIER  (effect size now computed INSIDE the loop)
print("\n" + SEP); print("3. CARRIER vs NON-CARRIER"); print(SEP)

MEASURES = {
    "DAM_score":         "DAM score",
    "DAM_noAPOE":        "DAM score, APOE removed",
    "Homeostatic_score": "Homeostatic score",
    "Control_score":     "Control score (NEG CONTROL)",
    "pct_DAMhigh":       f"% {DAM_HIGH}",
}
MEASURES = {k: v for k, v in MEASURES.items() if k in dd.columns}

rows = []
for m, label in MEASURES.items():
    a = num(dd.loc[dd.APOE4_status == "Carrier", m]).dropna()
    b = num(dd.loc[dd.APOE4_status == "Non-carrier", m]).dropna()
    r_eff, p = rank_biserial(a, b)          # <-- inside the loop, correct pairing
    rows.append({"measure": label, "carrier_median": a.median(),
                 "noncarrier_median": b.median(), "effect_size": r_eff,
                 "pval": p, "n_carrier": len(a), "n_noncarrier": len(b)})

res_bin = pd.DataFrame(rows)
print(res_bin.round(4).to_string(index=False))

# 4. E4 COPY NUMBER  (0, 1, or 2)
print("\n" + SEP); print("4. E4 COPY NUMBER"); print(SEP)

rows = []
for m, label in MEASURES.items():
    d = pd.concat([num(dd[m]).rename("y"), dd.E4_copies.rename("x")],
                  axis=1).dropna()
    rho, p = spearmanr(d.x, d.y)
    rows.append({"measure": label, "rho": rho, "pval": p, "n": len(d)})

res_dose = pd.DataFrame(rows)
print(res_dose.round(4).to_string(index=False))

print("\nmedian by copy number:")
print(dd.groupby("E4_copies")[list(MEASURES)].median().round(4).to_string())
print(dd.E4_copies.value_counts().sort_index().rename("n donors").to_string())

# 5. PLOTS
plot_measures = [m for m in ["DAM_score", "DAM_noAPOE", "pct_DAMhigh", "Control_score"]
                 if m in dd.columns]

fig, axes = plt.subplots(1, len(plot_measures), figsize=(4.6 * len(plot_measures), 4.8))
axes = np.atleast_1d(axes)
order = ["Non-carrier", "Carrier"]

for ax, m in zip(axes, plot_measures):
    sns.boxplot(data=dd, x="APOE4_status", y=m, order=order,
                hue="APOE4_status", hue_order=order, legend=False,
                palette={"Non-carrier": "steelblue", "Carrier": "tomato"}, ax=ax)
    sns.stripplot(data=dd, x="APOE4_status", y=m, order=order,
                  color="black", size=3, alpha=0.45, ax=ax)
    row = res_bin[res_bin.measure == MEASURES[m]].iloc[0]
    ax.set_title(f"{MEASURES[m]}\nr={row.effect_size:+.3f}, p={row.pval:.4f}",
                 fontweight="bold" if row.pval < 0.05 else "normal")
    ax.set_xlabel("")
    for i, lvl in enumerate(order):
        ax.text(i, ax.get_ylim()[0], f"n={(dd.APOE4_status == lvl).sum()}",
                ha="center", va="bottom", fontsize=8)

plt.suptitle("APOE4 status vs microglial state (donor level)", y=1.02)
plt.tight_layout()
plt.savefig("../figures/APOE4_status.png", dpi=300,
            bbox_inches="tight", facecolor="white")
plt.show(); plt.close()

# genotype plot - groups with under 3 donors are shown but marked
geno_order = [g for g in ["2/2", "2/3", "3/3", "2/4", "3/4", "4/4"]
              if g in dd.APOE_Genotype.unique()]
geno_n = dd.APOE_Genotype.value_counts()

fig, ax = plt.subplots(figsize=(9, 5))
sns.boxplot(data=dd, x="APOE_Genotype", y="DAM_score", order=geno_order,
            hue="APOE_Genotype", hue_order=geno_order, legend=False,
            palette="coolwarm", ax=ax)
sns.stripplot(data=dd, x="APOE_Genotype", y="DAM_score", order=geno_order,
              color="black", size=4, alpha=0.5, ax=ax)
for i, g in enumerate(geno_order):
    n = geno_n[g]
    ax.text(i, ax.get_ylim()[0], f"n={n}" + ("*" if n < 3 else ""),
            ha="center", va="bottom", fontsize=8,
            color="crimson" if n < 3 else "black")
ax.set_title("DAM score by APOE genotype (donor level)\n* = fewer than 3 donors, not interpretable")
ax.set_xlabel("APOE genotype"); ax.set_ylabel("Mean DAM score per donor")
plt.tight_layout()
plt.savefig("../figures/APOE_genotype.png", dpi=300,
            bbox_inches="tight", facecolor="white")
plt.show(); plt.close()

res_bin.to_csv("../results/apoe4_binary.csv", index=False)
res_dose.to_csv("../results/apoe4_dosage.csv", index=False)
print(f"\n{SEP}\nsaved -> ../results/apoe4_{{binary,dosage}}.csv")
# Out:
# ...
# 1. APOE-FREE SCORE
# ...
# DAM genes: 27 -> 26 (APOE removed)
# computing score 'DAM_noAPOE'
#     finished: added
#     'DAM_noAPOE', score of gene set (adata.obs).
#     450 total control genes are used. (0:00:01)
# DAM_score vs DAM_noAPOE: rho=+0.983  (high = APOE was not driving it)
#
# ...
# 2. DONOR TABLE
# ...
# donors: 84
# carriers: 25   non-carriers: 59
#
# E4 copies per donor:
# E4_copies
# 0    59
# 1    19
# 2     6
#
# genotype counts:
# APOE_Genotype
# 3/3    47
# 3/4    17
# 2/3    11
# 4/4     6
# 2/4     2
# 2/2     1
#
# ...
# 3. CARRIER vs NON-CARRIER
# ...
#                     measure  carrier_median  noncarrier_median  effect_size   pval  n_carrier  n_noncarrier
#                   DAM score          0.7144             0.6176       0.2529 0.0688         25            59
#     DAM score, APOE removed          0.6302             0.5586       0.2163 0.1198         25            59
#           Homeostatic score          1.0482             1.1195      -0.1431 0.3043         25            59
# ...

# %%
# Cell 11B - Recheck specificity using the complement-free control ---

# make sure the ordinal columns exist
maps = {
    "Braak":   ({"Braak 0":0,"Braak I":1,"Braak II":2,"Braak III":3,
                 "Braak IV":4,"Braak V":5,"Braak VI":6}, "Braak_num"),
    "CERAD score": ({"Absent":0,"Sparse":1,"Moderate":2,"Frequent":3}, "CERAD_num"),
    "Thal":    ({"Thal 0":0,"Thal 1":1,"Thal 2":2,"Thal 3":3,"Thal 4":4,"Thal 5":5}, "Thal_num"),
    "Cognitive Status": ({"No dementia":0,"Dementia":1}, "CogStatus_num"),
}
for src, (mp, new) in maps.items():
    if src in adata.obs.columns and new not in adata.obs.columns:
        adata.obs[new] = adata.obs[src].astype(str).map(mp)

SCORES = [s for s in ["DAM_score", "Control_score", "Control_clean"]
          if s in adata.obs.columns]
STAINS = [c for c in ["percent AT8 positive area_Grey matter",
                      "percent 6e10 positive area_Grey matter",
                      "percent Iba1 positive area_Grey matter"]
          if c in adata.obs.columns]
ORD = [c for c in ["Braak_num","CERAD_num","Thal_num","CogStatus_num"]
       if c in adata.obs.columns]

agg = {s: (s, "mean") for s in SCORES}
agg["n_cells"] = ("Donor ID", "size")
for c in ORD + STAINS:
    agg[c] = (c, "first")

t = adata.obs.groupby("Donor ID", observed=True).agg(**agg)
t = t[t.n_cells >= 50]

# add composition
comp = (adata.obs.groupby(["Donor ID","Supertype"], observed=True)
        .size().unstack(fill_value=0))
comp = comp[[c for c in comp.columns if "Micro" in str(c)]]
pct_t = comp.div(comp.sum(axis=1), axis=0) * 100
t["pct_DAMhigh"] = pct_t.loc[t.index, "Micro-PVM_3-SEAAD"].values

def num(s):
    return pd.to_numeric(pd.Series(s).astype(str), errors="coerce")

MEASURES = [m for m in ["DAM_score", "pct_DAMhigh", "Control_score", "Control_clean"]
            if m in t.columns]

rows = []
for var in ORD + STAINS:
    r = {"variable": var.replace("_num","").replace("percent ","").replace("_Grey matter","")}
    for m in MEASURES:
        d = pd.concat([num(t[m]), num(t[var])], axis=1).dropna()
        r[m] = spearmanr(d.iloc[:,0], d.iloc[:,1])[0]
    rows.append(r)

out = pd.DataFrame(rows).set_index("variable")
print(f"donors: {len(t)}\n")
print(out.round(3).to_string())
# Out:
# donors: 84
#
#                     DAM_score  pct_DAMhigh  Control_score
# variable
# Braak                   0.274        0.452          0.206
# CERAD                   0.263        0.518          0.264
# Thal                    0.258        0.446          0.272
# CogStatus               0.286        0.479          0.107
# AT8 positive area       0.231        0.510          0.196
# 6e10 positive area      0.213        0.344          0.266
# Iba1 positive area      0.278        0.072          0.085

# %%
# Cell 12 - Pseudobulk differential expression


SEP = "=" * 78

# CONFIG
# Grouping variable - must be assigned INDEPENDENTLY of expression data.
#   "Cognitive Status"  - binary, balanced, clinically assigned
#   "Braak"             - neuropathologist-assigned; uses BRAAK_LOW / BRAAK_HIGH
GROUP_VAR = "Cognitive Status"

BRAAK_LOW  = ["Braak 0", "Braak I", "Braak II"]
BRAAK_HIGH = ["Braak V", "Braak VI"]

MIN_CPM          = 1.0     # gene filter: expression floor
MIN_PROP_DONORS  = 0.5     # gene filter: fraction of donors that must clear it
MIN_CELLS_DONOR  = 50      # donors with fewer nuclei give unstable pseudobulk
EFFECT_THRESHOLD = 0.5     # |mean difference of log1p(CPM)| for the volcano

# 1. PSEUDOBULK FROM RAW COUNTS
print(SEP); print("1. PSEUDOBULK CONSTRUCTION"); print(SEP)

donors_vec = adata.obs["Donor ID"].astype(str).values
cats = pd.Categorical(donors_vec)
S = sp.csr_matrix((np.ones(len(cats.codes)), (cats.codes, np.arange(len(cats.codes)))),
                  shape=(len(cats.categories), len(cats.codes)))

counts = np.asarray((S @ adata.layers["UMIs"]).todense())      # donors x genes
n_cells = np.asarray(S.sum(axis=1)).ravel()
donor_ids = list(cats.categories)

# --- remove mitochondrial genes before CPM ---
gene_names = np.asarray(adata.var_names)
mt_mask = pd.Series(gene_names).str.startswith(("MT-", "MTRNR")).values

# how big is the MT share, and does it differ by group?
mt_frac = counts[:, mt_mask].sum(axis=1) / counts.sum(axis=1) * 100
print(f"\nremoving {mt_mask.sum()} mitochondrial genes")
print(f"MT share per donor: median={np.median(mt_frac):.2f}%  "
      f"range={mt_frac.min():.2f}-{mt_frac.max():.2f}%")

counts = counts[:, ~mt_mask]
gene_names = gene_names[~mt_mask]

print(f"pseudobulk matrix : {counts.shape[0]} donors x {counts.shape[1]:,} genes")
print(f"nuclei per donor  : min={n_cells.min():,.0f} "
      f"median={np.median(n_cells):,.0f} max={n_cells.max():,.0f}")

keep_d = n_cells >= MIN_CELLS_DONOR
if (~keep_d).any():
    print(f"dropping {(~keep_d).sum()} donor(s) with <{MIN_CELLS_DONOR} nuclei")
counts, n_cells = counts[keep_d], n_cells[keep_d]
donor_ids = [d for d, k in zip(donor_ids, keep_d) if k]

lib = counts.sum(axis=1, keepdims=True)
cpm = counts / lib * 1e6
logcpm = np.log1p(cpm)
print(f"donors retained   : {len(donor_ids)}")
print(f"pseudobulk depth  : median {np.median(lib):,.0f} UMI per donor")

# 2. GROUPING - independent of expression
print("\n" + SEP); print(f"2. GROUPING BY '{GROUP_VAR}' (independent of transcriptome)"); print(SEP)

meta = (adata.obs[["Donor ID"] + [c for c in
        ["Cognitive Status", "Braak", "CERAD score", "Thal", "APOE Genotype",
         "Age at Death", "Sex", "PMI"] if c in adata.obs.columns]]
        .drop_duplicates("Donor ID").set_index("Donor ID"))
meta.index = meta.index.astype(str)
meta = meta.loc[donor_ids]

if GROUP_VAR == "Braak":
    vals = meta["Braak"].astype(str).values
    lo, hi = np.isin(vals, BRAAK_LOW), np.isin(vals, BRAAK_HIGH)
    lo_name, hi_name = "Braak low", "Braak high"
else:
    vals = meta[GROUP_VAR].astype(str).values
    levels = pd.Series(vals).value_counts().index.tolist()
    assert len(levels) == 2, f"{GROUP_VAR} is not binary: {levels}"
    lo_name, hi_name = levels[1], levels[0]
    lo, hi = vals == lo_name, vals == hi_name

ok = lo | hi
print(f"{hi_name:<20} : {hi.sum()} donors")
print(f"{lo_name:<20} : {lo.sum()} donors")
print(f"excluded (intermediate): {(~ok).sum()}")
if min(lo.sum(), hi.sum()) < 8:
    print("\n  !! fewer than 8 donors in a group - underpowered.")

# 3. DEPTH CONFOUND CHECK 
print("\n" + SEP); print("3. IS THE GROUPING CONFOUNDED WITH DEPTH?"); print(SEP)

depth = lib.ravel()
confounded = False
for label, x in [("pseudobulk depth", depth), ("nuclei per donor", n_cells)]:
    a, b = x[hi], x[lo]
    _, p = mannwhitneyu(a, b, alternative="two-sided")
    ratio = np.median(a) / max(np.median(b), 1)
    flag = ""
    if p < 0.05:
        flag = "  <-- CONFOUNDED"
        confounded = True
    print(f"{label:<20} {hi_name} median={np.median(a):,.0f}  "
          f"{lo_name} median={np.median(b):,.0f}  ratio={ratio:.2f}  p={p:.3f}{flag}")

if "DAM_score" in adata.obs.columns:
    dam_donor = adata.obs.groupby("Donor ID")["DAM_score"].mean()
    dam_donor.index = dam_donor.index.astype(str)
    r, p = spearmanr(dam_donor.loc[donor_ids].values, depth)
    print(f"\ndonor DAM_score vs pseudobulk depth: rho={r:+.3f} p={p:.3f}")


if confounded:
    print("!! The groups differ in depth. Interpret DE cautiously")

# 4. GENE FILTERING
print("\n" + SEP); print("4. GENE FILTERING"); print(SEP)

expressed = (cpm[ok] > MIN_CPM).mean(axis=0) >= MIN_PROP_DONORS
print(f"genes before : {len(gene_names):,}")
print(f"genes after  : {expressed.sum():,}  "
      f"(CPM>{MIN_CPM} in >={MIN_PROP_DONORS:.0%} of donors)")
print(f"removed      : {(~expressed).sum():,} lowly/never-detected genes")

G = gene_names[expressed]
Y = logcpm[np.ix_(ok, expressed)]
lo_ok, hi_ok = lo[ok], hi[ok]

# 5. DIFFERENTIAL EXPRESSION
print("\n" + SEP); print("5. DIFFERENTIAL EXPRESSION"); print(SEP)

n_hi, n_lo = hi_ok.sum(), lo_ok.sum()
stat = np.zeros(len(G)); pvals = np.ones(len(G)); delta = np.zeros(len(G))
for j in range(len(G)):
    a, b = Y[hi_ok, j], Y[lo_ok, j]
    try:
        u, p = mannwhitneyu(a, b, alternative="two-sided")
        stat[j] = 2 * u / (n_hi * n_lo) - 1          # rank-biserial, -1..1
    except ValueError:
        u, p, stat[j] = np.nan, 1.0, np.nan
    pvals[j] = p
    delta[j] = a.mean() - b.mean()

qvals = multipletests(pvals, method="fdr_bh")[1]
res = pd.DataFrame({"gene": G, "rank_biserial": stat,
                    "mean_diff_log1p_CPM": delta, "pval": pvals, "qval": qvals})

sig = res[res.qval < 0.05]
up = sig[sig.mean_diff_log1p_CPM > EFFECT_THRESHOLD]
dn = sig[sig.mean_diff_log1p_CPM < -EFFECT_THRESHOLD]

print(f"genes tested            : {len(res):,}")
print(f"FDR < 0.05              : {len(sig):,}")
print(f"  up in {hi_name:<15}: {len(up):,}")
print(f"  down in {hi_name:<13}: {len(dn):,}")

if len(sig):
    frac_up = (sig.mean_diff_log1p_CPM > 0).mean()
    print(f"\nfraction of significant genes moving UP: {frac_up:.1%}")
    if frac_up > 0.85 or frac_up < 0.15:
        print("  !! Strongly one-sided.")

# 6. SIGNATURE GENES vs NOVEL GENES
print("\n" + SEP); print("6. RESULTS, SEPARATED"); print(SEP)

sig_set = {g.upper() for g in dam_genes_filtered} | {g.upper() for g in homeostatic_genes_filtered}
res["in_signature"] = res.gene.str.upper().isin(sig_set)

print("--- signature genes (pre-selected; NOT discoveries) ---")
sg = res[res.in_signature].copy()
sg["set"] = np.where(sg.gene.str.upper().isin({g.upper() for g in dam_genes_filtered}),
                     "DAM", "Homeostatic")
print(sg.sort_values("mean_diff_log1p_CPM", ascending=False)
      [["gene", "set", "rank_biserial", "mean_diff_log1p_CPM", "qval"]]
      .round(4).to_string(index=False))

novel = sig[~sig.gene.str.upper().isin(sig_set)]
print(f"\n--- novel hits (signature genes excluded): {len(novel)} ---")
print("\nTop 15 up:")
print(novel.nlargest(15, "mean_diff_log1p_CPM")
      [["gene", "rank_biserial", "mean_diff_log1p_CPM", "qval"]].round(4).to_string(index=False))
print("\nTop 15 down:")
print(novel.nsmallest(15, "mean_diff_log1p_CPM")
      [["gene", "rank_biserial", "mean_diff_log1p_CPM", "qval"]].round(4).to_string(index=False))

unannot = novel[novel.gene.str.match(r"^(AC|AL|AP|LINC|CTD-|RP\d)")]
if len(unannot):
    print(f"\n  {len(unannot)} of {len(novel)} novel hits are unannotated "
          f"lncRNA/clone identifiers ({100*len(unannot)/max(len(novel),1):.0f}%).")

# 7. GENE SET ENRICHMENT

ranks = rankdata(res.mean_diff_log1p_CPM.values)
gene_rank = dict(zip(res.gene.str.upper(), ranks))
n_tot = len(res)


def enrich(genes, label):
    present = [g.upper() for g in genes if g.upper() in gene_rank]
    missing = [g for g in genes if g.upper() not in gene_rank]
    if len(present) < 3:
        print(f"{label:<14} too few genes survived filtering ({len(present)})")
        return
    inr = np.array([gene_rank[g] for g in present])
    outr = np.array([r for g, r in gene_rank.items() if g not in set(present)])
    _, p = mannwhitneyu(inr, outr, alternative="two-sided")
    pctl = 100 * inr.mean() / n_tot
    print(f"{label:<14} n={len(present):<3} mean rank percentile={pctl:5.1f}%  "
          f"{'UP' if pctl > 50 else 'DOWN':<4} p={p:.3e}")
    if missing:
        print(f"{'':<14} dropped by the expression filter: {missing}")


enrich(dam_genes_filtered, "DAM")
enrich(homeostatic_genes_filtered, "Homeostatic")
if "control_genes_filtered" in dir():
    enrich(control_genes_filtered, "Control")
    ctrl_clean = [g for g in control_genes_filtered
                  if g.upper() not in {"C1QA", "C1QB", "C1QC"}]
    enrich(ctrl_clean, "Control_clean")


# 8. VOLCANO
fig, ax = plt.subplots(figsize=(9.5, 6.5))
res["color"] = "lightgrey"
res.loc[(res.qval < 0.05) & (res.mean_diff_log1p_CPM > EFFECT_THRESHOLD), "color"] = "tomato"
res.loc[(res.qval < 0.05) & (res.mean_diff_log1p_CPM < -EFFECT_THRESHOLD), "color"] = "steelblue"

ax.scatter(res.mean_diff_log1p_CPM, -np.log10(res.qval + 1e-300),
           c=res.color, alpha=0.5, s=10)
# signature genes marked separately so they are never read as discoveries
sgp = res[res.in_signature]
ax.scatter(sgp.mean_diff_log1p_CPM, -np.log10(sgp.qval + 1e-300),
           facecolors="none", edgecolors="black", s=45, linewidth=0.9,
           label="signature gene (pre-selected)")

for _, r in pd.concat([novel.nlargest(10, "mean_diff_log1p_CPM"),
                       novel.nsmallest(10, "mean_diff_log1p_CPM")]).iterrows():
    ax.annotate(r.gene, (r.mean_diff_log1p_CPM, -np.log10(r.qval + 1e-300)),
                fontsize=7, alpha=0.8)

for x in (-EFFECT_THRESHOLD, EFFECT_THRESHOLD):
    ax.axvline(x, color="black", ls="--", lw=0.8)
ax.axhline(-np.log10(0.05), color="black", ls="--", lw=0.8)
ax.set_xlabel(f"Mean difference of log1p(CPM)  ({hi_name} vs {lo_name})")
ax.set_ylabel("-log10(adjusted p-value)")
ax.set_title(f"Differential expression: {hi_name} vs {lo_name}\n"
             f"Pseudobulk, donor level, n={n_hi} vs {n_lo}, "
             f"{len(res):,} genes after filtering")
ax.legend(fontsize=8)
plt.tight_layout()
plt.savefig("../figures/volcano_DE.png", dpi=300, bbox_inches="tight", facecolor="white")
plt.show()
plt.close()

res.drop(columns="color").to_csv("../results/de_pseudobulk.csv", index=False)
print(f"\n{SEP}\nsaved -> ../results/de_pseudobulk.csv")
# Out:
# ...
# 1. PSEUDOBULK CONSTRUCTION
# ...
#
# removing 24 mitochondrial genes
# MT share per donor: median=0.21%  range=0.02-1.65%
# pseudobulk matrix : 84 donors x 36,577 genes
# nuclei per donor  : min=63 median=376 max=1,034
# donors retained   : 84
# pseudobulk depth  : median 2,128,796 UMI per donor
#
# ...
# 2. GROUPING BY 'Cognitive Status' (independent of transcriptome)
# ...
# No dementia          : 42 donors
# Dementia             : 42 donors
# excluded (intermediate): 0
#
# ...
# 3. IS THE GROUPING CONFOUNDED WITH DEPTH?
# ...
# pseudobulk depth     No dementia median=1,959,892  Dementia median=2,298,460  ratio=0.85  p=0.354
# nuclei per donor     No dementia median=376  Dementia median=367  ratio=1.02  p=0.918
#
# donor DAM_score vs pseudobulk depth: rho=-0.090 p=0.417
#
# ...
# 4. GENE FILTERING
# ...
# genes before : 36,577
# genes after  : 17,351  (CPM>1.0 in >=50% of donors)
# removed      : 19,226 lowly/never-detected genes
#
# ...
# 5. DIFFERENTIAL EXPRESSION
# ...
